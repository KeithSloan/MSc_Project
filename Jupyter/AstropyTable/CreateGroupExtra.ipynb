# %%
from astropy.table import Table, join
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import pandas as pd


ForGroup = Table.read('../../GAMA_DATA/G3CFoFGroupv10.fits')

## Clean Data

GroupGal = Table.read('../../GAMA_DATA/G3CGalv10.fits')

StellarMasses = Tabel.read('../../GAMA_DATA/StellarMassesv19.fits')

RErange = Table.read('../../GAMA_Data/Data+LocalGroup.fits')
## Clean Data

RErange = RErange[RErange['SurfaceDensityFlag'] == 0]
#RErange = RErange[RErange['SurfaceDensity'] < 50]
RErange = RErange[RErange['AGEDenParFlag'] == 0]
RErange = RErange[RErange['CountInCylFlag'] == 0]
RErange = RErange[RErange['uminusr']> 0.001]
## Red Ellipitcals
RErange = RErange[RErange['ELLIPTICAL_CODE'] == 1]



alphaVal = .3
binCount = 100

# Create Group Summary Data
empty  = 0
single = 0
for grp in ForGroup['GroupID'] :
    grpRed   = 0
    grpMetal = 0
    #print(f" ===== {grp}")    
    #subGroup = RErange[RErange['GroupID'] == grp ]
    #print(subGroup.conames)
    num = len(subGroup['CATAID'])
    if  num > 0 :
        print(f" ===== GroupID  {grp}")
        if num == 1 : single += 1
        for gal in subGroup['CATAID'] :
            galEntry =
            print(f"Gal : CATAID {gal}")
            grpRed += subGroup[]
    else :
        #print('Empty Group')
        empty += 1
totNumGrp = len(ForGroup['GroupID'])        
print(f"Total number of Groups : {totNumGrp}") 
print(f"Empty Groups {empty}")
print(f"Non Empty Groups : {totNumGrp - empty}")
print(f"Group with Single Galaxy {single}")
# Out:
#  ===== 100006
# Gal : 372197
# Gal : 372193
# Gal : 372192
# Gal : 376633
# Gal : 372176
# Gal : 301636
# Gal : 301555
# Gal : 301559
# Gal : 301562
# Gal : 301596
# Gal : 301599
# Gal : 301601
# Gal : 301606
# Gal : 301608
# Gal : 301609
# Gal : 301615
# Gal : 372140
# Gal : 372127
# Gal : 372124
# Gal : 372123
# Gal : 372142
# Gal : 372133
#  ===== 100017
# Gal : 598929
# Gal : 598939
# Gal : 598947
# Gal : 598948
# Gal : 214267
# Gal : 214285
# Gal : 214250
# Gal : 214264
# Gal : 214269
#  ===== 100025
# Gal : 381227
# Gal : 381229
# Gal : 381219
# Gal : 381217
# Gal : 381208
# Gal : 381207
# Gal : 381157
# Gal : 381206
# Gal : 381151
# Gal : 381155
#  ===== 100055
# Gal : 517205
# Gal : 517206
# Gal : 517210
# Gal : 517214
# Gal : 517215
# Gal : 517218
# Gal : 517211
# Gal : 517244
#  ===== 100067
# Gal : 279874
# Gal : 373160
# Gal : 373173
# Gal : 373163
# Gal : 373161
# Gal : 279878
# Gal : 279881
# Gal : 373159
# Gal : 279910
# Gal : 279913
# Gal : 373156
# Gal : 373165
# Gal : 373168
# Gal : 373167
# Gal : 373171
#  ===== 100072
# Gal : 417447
# Gal : 417451
# Gal : 417440
#  ===== 100084
# Gal : 381357
# Gal : 323593
# Gal : 323594
# Gal : 323597
#  ===== 100086
# Gal : 346888
# Gal : 346890
# Gal : 346887
# Gal : 346894
# Gal : 382154
#  ===== 100095
# Gal : 388513
# Gal : 365386
#  ===== 100100
# Gal : 3912128
# Gal : 3912185
# Gal : 3616577
# Gal : 3616604
# Gal : 3616588
# Gal : 3616371
# Gal : 3616593
#  ===== 100108
# Gal : 278350
# Gal : 371175
# Gal : 371180
#  ===== 100110
# Gal : 345767
# Gal : 381001
# Gal : 345770
# Gal : 345766
# Gal : 345758
# Gal : 345779
# Gal : 345765
# Gal : 381006
# Gal : 345755
#  ===== 100112
# Gal : 347398
# Gal : 347394
# Gal : 347396
# Gal : 347395
#  ===== 100142
# Gal : 371220
# Gal : 371186
# Gal : 371218
# Gal : 371217
#  ===== 100154
# Gal : 600929
# Gal : 600915
# Gal : 216396
# Gal : 600973
#  ===== 100162
# Gal : 3890681
# Gal : 3890660
# Gal : 3890637
# Gal : 3890632
# Gal : 3890636
#  ===== 100168
# Gal : 204857
# Gal : 204839
# Gal : 575411
# Gal : 575412
# Gal : 204896
#  ===== 100176
# Gal : 279941
# Gal : 279934
#  ===== 100191
# Gal : 301523
# Gal : 376586
#  ===== 100227
# Gal : 3627084
# Gal : 3627036
# Gal : 3627201
# Gal : 3627106
# Gal : 3627095
#  ===== 100242
# Gal : 210159
# Gal : 210147
#  ===== 100268
# Gal : 388146
# Gal : 388166
#  ===== 100280
# Gal : 548835
#  ===== 100294
# Gal : 599834
# Gal : 215052
#  ===== 100305
# Gal : 3600154
# Gal : 3599818
# Gal : 3600083
# Gal : 3600120
# Gal : 3600124
# Gal : 3600160
# Gal : 3600126
#  ===== 100312
# Gal : 3878647
# Gal : 3878832
# Gal : 3878846
# Gal : 3878851
#  ===== 100352
# Gal : 300657
# Gal : 300658
# Gal : 300659
#  ===== 100356
# Gal : 376247
#  ===== 100357
# Gal : 301761
# Gal : 301754
#  ===== 100365
# Gal : 325321
# Gal : 325322
#  ===== 100380
# Gal : 375560
# Gal : 375564
# Gal : 375561
# Gal : 375598
#  ===== 100383
# Gal : 376115
# Gal : 376111
# Gal : 376097
#  ===== 100385
# Gal : 376703
# Gal : 376705
#  ===== 100389
# Gal : 417475
#  ===== 100446
# Gal : 3874874
#  ===== 100486
# Gal : 208591
#  ===== 100490
# Gal : 208898
#  ===== 100492
# Gal : 209680
# Gal : 209681
#  ===== 100501
# Gal : 216225
# Gal : 216226
# Gal : 216219
#  ===== 100507
# Gal : 278840
#  ===== 100529
# Gal : 323566
# Gal : 323558
#  ===== 100544
# Gal : 345848
# Gal : 345845
#  ===== 100548
# Gal : 346837
#  ===== 100560
# Gal : 372569
# Gal : 372574
# Gal : 372567
#  ===== 100568
# Gal : 377675
# Gal : 377668
#  ===== 100570
# Gal : 380671
# Gal : 380669
# Gal : 380670
#  ===== 100588
# Gal : 345852
#  ===== 100599
# Gal : 388558
# Gal : 388559
#  ===== 100603
# Gal : 417471
# Gal : 417481
# Gal : 417480
#  ===== 100613
# Gal : 418743
#  ===== 100663
# Gal : 599838
#  ===== 100668
# Gal : 600782
#  ===== 100672
# Gal : 622350
# Gal : 622352
#  ===== 100708
# Gal : 3618160
# Gal : 3618170
# Gal : 3618157
#  ===== 100710
# Gal : 3625080
# Gal : 3625070
#  ===== 100785
# Gal : 203833
#  ===== 100805
# Gal : 209368
#  ===== 100813
# Gal : 210748
#  ===== 100853
# Gal : 278725
#  ===== 100856
# Gal : 279324
# Gal : 279326
#  ===== 100892
# Gal : 302894
# Gal : 377965
#  ===== 100895
# Gal : 323246
#  ===== 100925
# Gal : 345927
#  ===== 100944
# Gal : 347904
#  ===== 100951
# Gal : 371207
# Gal : 371208
# Gal : 371172
#  ===== 100965
# Gal : 375782
# Gal : 375787
# Gal : 375790
# Gal : 375792
#  ===== 100987
# Gal : 380697
#  ===== 101001
# Gal : 381980
# Gal : 381979
#  ===== 101008
# Gal : 383049
#  ===== 101010
# Gal : 383147
#  ===== 101014
# Gal : 386311
#  ===== 101163
# Gal : 599000
#  ===== 101184
# Gal : 601325
#  ===== 101248
# Gal : 3607126
# Gal : 3902732
# Gal : 3607125
#  ===== 101272
# Gal : 3629663
#  ===== 101283
# Gal : 3634556
#  ===== 101324
# Gal : 3904345
# Gal : 3904357
#  ===== 101327
# Gal : 3907431
# Gal : 3907189
#  ===== 101330
# Gal : 3907960
#  ===== 101404
# Gal : 202480
#  ===== 101416
# Gal : 203140
#  ===== 101440
# Gal : 204101
#  ===== 101461
# Gal : 208560
#  ===== 101465
# Gal : 208679
# Gal : 208652
# Gal : 208666
#  ===== 101509
# Gal : 210471
# Gal : 210467
# Gal : 210480
#  ===== 101541
# Gal : 215289
#  ===== 101561
# Gal : 623143
#  ===== 101581
# Gal : 622210
# Gal : 278493
#  ===== 101588
# Gal : 278773
#  ===== 101592
# Gal : 278994
#  ===== 101649
# Gal : 301937
#  ===== 101664
# Gal : 302684
#  ===== 101680
# Gal : 375599
# Gal : 323005
#  ===== 101711
# Gal : 324349
#  ===== 101722
# Gal : 324845
#  ===== 101734
# Gal : 325476
#  ===== 101741
# Gal : 345523
#  ===== 101763
# Gal : 346623
#  ===== 101772
# Gal : 382398
#  ===== 101785
# Gal : 347403
# Gal : 347432
#  ===== 101786
# Gal : 347471
#  ===== 101810
# Gal : 365396
# Gal : 365391
#  ===== 101826
# Gal : 371295
#  ===== 101850
# Gal : 372121
# Gal : 372132
#  ===== 101853
# Gal : 372384
# Gal : 372385
#  ===== 101888
# Gal : 376066
#  ===== 101912
# Gal : 377463
#  ===== 101923
# Gal : 377966
# Gal : 377917
#  ===== 101934
# Gal : 380740
#  ===== 101935
# Gal : 380734
#  ===== 101962
# Gal : 382215
# Gal : 382216
#  ===== 101989
# Gal : 383265
# Gal : 383275
#  ===== 101991
# Gal : 386224
#  ===== 101992
# Gal : 386247
#  ===== 101993
# Gal : 345814
#  ===== 102024
# Gal : 387680
# Gal : 387681
# Gal : 387682
#  ===== 102043
# Gal : 417452
#  ===== 102045
# Gal : 417486
#  ===== 102089
# Gal : 419280
#  ===== 102116
# Gal : 422606
#  ===== 102266
# Gal : 550227
# Gal : 550225
#  ===== 102276
# Gal : 551075
# Gal : 551067
#  ===== 102326
# Gal : 574691
#  ===== 102338
# Gal : 575268
# Gal : 575237
#  ===== 102388
# Gal : 600743
#  ===== 102397
# Gal : 601095
#  ===== 102403
# Gal : 601283
#  ===== 102415
# Gal : 622082
#  ===== 102419
# Gal : 622349
#  ===== 102448
# Gal : 623677
#  ===== 102649
# Gal : 3909358
# Gal : 3630895
#  ===== 102651
# Gal : 3911242
#  ===== 102740
# Gal : 3886434
#  ===== 102963
# Gal : 198505
# Gal : 198507
#  ===== 103114
# Gal : 574423
#  ===== 103233
# Gal : 208868
#  ===== 103234
# Gal : 208860
#  ===== 103243
# Gal : 208981
#  ===== 103356
# Gal : 210375
#  ===== 103378
# Gal : 210669
#  ===== 103392
# Gal : 210851
#  ===== 103403
# Gal : 214293
#  ===== 103425
# Gal : 214678
#  ===== 103443
# Gal : 215039
#  ===== 103450
# Gal : 215160
#  ===== 103536
# Gal : 216156
#  ===== 103619
# Gal : 278355
#  ===== 103620
# Gal : 278368
#  ===== 103658
# Gal : 278804
#  ===== 103703
# Gal : 279498
#  ===== 103735
# Gal : 279944
#  ===== 103779
# Gal : 300695
#  ===== 103787
# Gal : 300777
#  ===== 103938
# Gal : 302778
#  ===== 103959
# Gal : 302995
#  ===== 104053
# Gal : 323886
#  ===== 104117
# Gal : 324847
#  ===== 104156
# Gal : 325381
#  ===== 104187
# Gal : 345647
# Gal : 345653
#  ===== 104217
# Gal : 346006
#  ===== 104219
# Gal : 346010
#  ===== 104407
# Gal : 370941
#  ===== 104414
# Gal : 370987
#  ===== 104482
# Gal : 371882
#  ===== 104519
# Gal : 372446
# Gal : 372447
#  ===== 104543
# Gal : 372763
#  ===== 104576
# Gal : 373235
# Gal : 373233
#  ===== 104736
# Gal : 377410
#  ===== 104785
# Gal : 380674
#  ===== 104806
# Gal : 380972
#  ===== 104812
# Gal : 381068
# Gal : 381075
#  ===== 104831
# Gal : 381417
#  ===== 104834
# Gal : 381465
#  ===== 104897
# Gal : 382640
#  ===== 104954
# Gal : 386213
#  ===== 104967
# Gal : 386406
#  ===== 104972
# Gal : 386481
#  ===== 105049
# Gal : 387722
#  ===== 105119
# Gal : 516975
#  ===== 105126
# Gal : 417446
#  ===== 105491
# Gal : 517088
#  ===== 105713
# Gal : 536570
# Gal : 536567
#  ===== 105784
# Gal : 549223
#  ===== 105785
# Gal : 549296
#  ===== 105789
# Gal : 549343
#  ===== 105835
# Gal : 549981
# Gal : 549980
#  ===== 105884
# Gal : 550754
#  ===== 106137
# Gal : 599076
#  ===== 106237
# Gal : 600684
#  ===== 106274
# Gal : 601248
#  ===== 106275
# Gal : 601251
#  ===== 106329
# Gal : 622163
#  ===== 106377
# Gal : 623017
# Gal : 623018
#  ===== 106421
# Gal : 623736
#  ===== 106805
# Gal : 3606022
#  ===== 106897
# Gal : 3616601
# Gal : 3616607
#  ===== 106921
# Gal : 3622141
#  ===== 107025
# Gal : 3633567
#  ===== 107172
# Gal : 3875207
# Gal : 3875229
#  ===== 107196
# Gal : 3878561
# Gal : 3878584
#  ===== 107198
# Gal : 3878612
#  ===== 107388
# Gal : 3904801
#  ===== 107414
# Gal : 3908399
#  ===== 200007
# Gal : 171688
# Gal : 171725
# Gal : 171710
# Gal : 124416
# Gal : 124433
# Gal : 124430
# Gal : 124469
# Gal : 124405
# Gal : 124406
# Gal : 124408
# Gal : 124410
# Gal : 124429
# Gal : 124418
# Gal : 124426
# Gal : 124461
# Gal : 124419
# Gal : 124420
# Gal : 124434
# Gal : 124425
# Gal : 124388
# Gal : 124457
# Gal : 124456
# Gal : 124371
# Gal : 124448
# Gal : 124435
# Gal : 124372
# Gal : 124377
# Gal : 124378
# Gal : 124443
# Gal : 124441
# Gal : 124440
# Gal : 124437
#  ===== 200022
# Gal : 130274
# Gal : 130216
# Gal : 177301
# Gal : 177358
# Gal : 177342
# Gal : 177338
# Gal : 177336
# Gal : 177335
# Gal : 177334
# Gal : 177333
# Gal : 177371
# Gal : 130264
# Gal : 177381
# Gal : 130214
# Gal : 130213
# Gal : 130205
#  ===== 200025
# Gal : 273851
# Gal : 273848
# Gal : 273846
# Gal : 273850
# Gal : 273852
# Gal : 273849
# Gal : 273888
# Gal : 273845
# Gal : 273892
# Gal : 273902
# Gal : 273841
# Gal : 273887
# Gal : 273833
# Gal : 273838
# Gal : 221281
#  ===== 200030
# Gal : 177197
# Gal : 177165
# Gal : 177225
# Gal : 177229
# Gal : 130139
# Gal : 130143
# Gal : 177232
# Gal : 177260
# Gal : 177247
# Gal : 177238
# Gal : 177234
#  ===== 200033
# Gal : 123801
# Gal : 171158
# Gal : 123802
# Gal : 171151
# Gal : 171152
# Gal : 123813
# Gal : 123843
# Gal : 171149
# Gal : 123807
# Gal : 171139
# Gal : 171172
# Gal : 171115
# Gal : 171116
# Gal : 171133
# Gal : 171119
# Gal : 171136
# Gal : 123786
# Gal : 123787
#  ===== 200056
# Gal : 136616
# Gal : 184274
# Gal : 184261
# Gal : 136602
# Gal : 136624
#  ===== 200058
# Gal : 136362
# Gal : 184046
# Gal : 184045
# Gal : 184044
# Gal : 184043
# Gal : 184042
#  ===== 200074
# Gal : 172692
# Gal : 172700
# Gal : 172726
# Gal : 172729
# Gal : 172730
# Gal : 172734
#  ===== 200083
# Gal : 177473
# Gal : 177435
# Gal : 177441
# Gal : 177434
# Gal : 177428
# Gal : 137033
#  ===== 200084
# Gal : 220276
# Gal : 220280
# Gal : 272885
# Gal : 272857
# Gal : 272835
# Gal : 272831
# Gal : 220282
# Gal : 220284
# Gal : 272833
#  ===== 200085
# Gal : 396742
# Gal : 396743
# Gal : 396762
# Gal : 396798
# Gal : 396800
# Gal : 396761
#  ===== 200090
# Gal : 23630
# Gal : 23623
# Gal : 23625
#  ===== 200091
# Gal : 742632
# Gal : 534758
# Gal : 30361
# Gal : 30367
# Gal : 534755
# Gal : 30393
# Gal : 30364
#  ===== 200103
# Gal : 584683
# Gal : 584682
# Gal : 584648
# Gal : 584719
# Gal : 55009
#  ===== 200123
# Gal : 536964
# Gal : 536963
# Gal : 536994
# Gal : 537009
# Gal : 536962
#  ===== 200140
# Gal : 143735
# Gal : 143778
# Gal : 143786
# Gal : 143747
# Gal : 143727
#  ===== 200142
# Gal : 144333
# Gal : 144330
# Gal : 144335
# Gal : 144336
# Gal : 144365
# Gal : 144342
# Gal : 144340
# Gal : 144339
# Gal : 144337
#  ===== 200164
# Gal : 23118
# Gal : 23117
# Gal : 23114
#  ===== 200167
# Gal : 30467
# Gal : 30470
# Gal : 30469
# Gal : 30466
# Gal : 30471
# Gal : 30473
#  ===== 200168
# Gal : 39472
# Gal : 39479
# Gal : 39477
# Gal : 559459
# Gal : 39485
# Gal : 559428
#  ===== 200169
# Gal : 41051
# Gal : 691327
# Gal : 41059
# Gal : 41060
# Gal : 41062
#  ===== 200179
# Gal : 137037
#  ===== 200192
# Gal : 272997
# Gal : 220438
# Gal : 220437
#  ===== 200193
# Gal : 220462
# Gal : 220465
# Gal : 220467
#  ===== 200199
# Gal : 536233
# Gal : 536232
# Gal : 536231
# Gal : 536237
# Gal : 536235
# Gal : 536226
#  ===== 200201
# Gal : 560406
#  ===== 200209
# Gal : 22596
# Gal : 22597
# Gal : 22582
# Gal : 22595
# Gal : 22598
#  ===== 200211
# Gal : 30615
# Gal : 30621
#  ===== 200223
# Gal : 97908
# Gal : 6975
# Gal : 6974
# Gal : 97907
#  ===== 200232
# Gal : 124806
#  ===== 200263
# Gal : 8953
# Gal : 8954
#  ===== 200278
# Gal : 40445
#  ===== 200279
# Gal : 41135
#  ===== 200286
# Gal : 84764
# Gal : 84740
# Gal : 84743
# Gal : 84763
#  ===== 200303
# Gal : 132367
#  ===== 200304
# Gal : 137080
# Gal : 137081
#  ===== 200305
# Gal : 137206
# Gal : 184686
# Gal : 137208
#  ===== 200328
# Gal : 186470
# Gal : 186468
#  ===== 200330
# Gal : 219730
# Gal : 219728
#  ===== 200332
# Gal : 220221
# Gal : 220216
#  ===== 200338
# Gal : 396834
# Gal : 271611
# Gal : 396802
# Gal : 271617
# Gal : 396801
#  ===== 200371
# Gal : 7969
# Gal : 7970
# Gal : 84897
#  ===== 200388
# Gal : 40743
#  ===== 200392
# Gal : 41180
# Gal : 41181
# Gal : 41172
#  ===== 200394
# Gal : 54274
# Gal : 54270
# Gal : 54263
#  ===== 200397
# Gal : 55097
# Gal : 55098
#  ===== 200400
# Gal : 70022
# Gal : 693965
# Gal : 70017
# Gal : 70016
# Gal : 70021
#  ===== 200410
# Gal : 99035
# Gal : 99028
# Gal : 99034
#  ===== 200411
# Gal : 23381
#  ===== 200421
# Gal : 123253
#  ===== 200431
# Gal : 130971
# Gal : 130981
# Gal : 130983
#  ===== 200432
# Gal : 131421
# Gal : 131420
#  ===== 200436
# Gal : 136799
# Gal : 136861
#  ===== 200456
# Gal : 172247
#  ===== 200460
# Gal : 177671
# Gal : 177679
# Gal : 177673
# Gal : 177670
#  ===== 200483
# Gal : 221017
# Gal : 221013
#  ===== 200527
# Gal : 54923
# Gal : 560341
# Gal : 560339
# Gal : 560337
#  ===== 200534
# Gal : 56005
# Gal : 585698
# Gal : 56006
# Gal : 585750
# Gal : 55965
#  ===== 200536
# Gal : 610386
# Gal : 610396
#  ===== 200537
# Gal : 610435
# Gal : 610404
#  ===== 200559
# Gal : 23070
# Gal : 23082
#  ===== 200560
# Gal : 23278
# Gal : 23276
#  ===== 200570
# Gal : 30945
# Gal : 30953
#  ===== 200578
# Gal : 31623
#  ===== 200584
# Gal : 39396
# Gal : 39388
#  ===== 200588
# Gal : 40304
#  ===== 200590
# Gal : 40491
# Gal : 40490
#  ===== 200599
# Gal : 54202
#  ===== 200600
# Gal : 584050
# Gal : 54381
#  ===== 200604
# Gal : 692612
# Gal : 54917
# Gal : 54918
#  ===== 200622
# Gal : 70640
#  ===== 200623
# Gal : 70802
#  ===== 200624
# Gal : 71063
# Gal : 71028
#  ===== 200628
# Gal : 84734
# Gal : 84752
#  ===== 200636
# Gal : 97915
# Gal : 97926
# Gal : 97918
# Gal : 21953
#  ===== 200661
# Gal : 123884
#  ===== 200671
# Gal : 129977
#  ===== 200682
# Gal : 136313
# Gal : 136308
# Gal : 136312
#  ===== 200700
# Gal : 144640
#  ===== 200720
# Gal : 170649
#  ===== 200725
# Gal : 171175
# Gal : 171177
#  ===== 200760
# Gal : 221283
#  ===== 200768
# Gal : 271538
#  ===== 200775
# Gal : 272820
# Gal : 272824
# Gal : 272825
# Gal : 272829
#  ===== 200793
# Gal : 535014
#  ===== 200808
# Gal : 560918
#  ===== 200820
# Gal : 585215
# Gal : 585216
#  ===== 200821
# Gal : 585624
#  ===== 200826
# Gal : 609246
#  ===== 200836
# Gal : 7742
# Gal : 7716
# Gal : 7715
#  ===== 200840
# Gal : 7992
#  ===== 200858
# Gal : 22279
#  ===== 200861
# Gal : 22457
#  ===== 200862
# Gal : 22883
#  ===== 200890
# Gal : 32195
# Gal : 32196
#  ===== 200891
# Gal : 32270
# Gal : 32271
#  ===== 200931
# Gal : 54500
#  ===== 200974
# Gal : 84680
#  ===== 200979
# Gal : 85012
#  ===== 200983
# Gal : 85205
#  ===== 200988
# Gal : 85484
#  ===== 201007
# Gal : 98880
#  ===== 201011
# Gal : 99031
# Gal : 98991
#  ===== 201061
# Gal : 129976
#  ===== 201062
# Gal : 130030
#  ===== 201079
# Gal : 131876
# Gal : 131877
# Gal : 131878
#  ===== 201103
# Gal : 143269
#  ===== 201106
# Gal : 143599
#  ===== 201111
# Gal : 144122
#  ===== 201157
# Gal : 171642
# Gal : 171643
#  ===== 201169
# Gal : 172214
# Gal : 172215
#  ===== 201182
# Gal : 177185
# Gal : 177228
#  ===== 201186
# Gal : 177638
# Gal : 177642
#  ===== 201191
# Gal : 177922
# Gal : 177969
#  ===== 201192
# Gal : 178030
#  ===== 201210
# Gal : 184202
#  ===== 201215
# Gal : 184658
#  ===== 201223
# Gal : 185567
#  ===== 201224
# Gal : 185596
# Gal : 185595
#  ===== 201231
# Gal : 186537
# Gal : 186538
#  ===== 201243
# Gal : 220341
# Gal : 220333
#  ===== 201250
# Gal : 221338
# Gal : 221339
#  ===== 201266
# Gal : 22583
# Gal : 272190
#  ===== 201270
# Gal : 272438
#  ===== 201277
# Gal : 24200
# Gal : 273654
#  ===== 201304
# Gal : 396865
# Gal : 396838
#  ===== 201327
# Gal : 535772
# Gal : 535764
#  ===== 201335
# Gal : 536454
#  ===== 201354
# Gal : 560287
# Gal : 560288
#  ===== 201366
# Gal : 561597
#  ===== 201375
# Gal : 583723
#  ===== 201408
# Gal : 610159
# Gal : 70188
#  ===== 201452
# Gal : 7842
# Gal : 7839
#  ===== 201474
# Gal : 8812
#  ===== 201523
# Gal : 23153
#  ===== 201525
# Gal : 23266
# Gal : 23265
#  ===== 201528
# Gal : 23341
#  ===== 201543
# Gal : 273542
# Gal : 273546
#  ===== 201570
# Gal : 30922
#  ===== 201596
# Gal : 32017
#  ===== 201597
# Gal : 32019
#  ===== 201602
# Gal : 32200
#  ===== 201618
# Gal : 39196
# Gal : 39197
#  ===== 201647
# Gal : 40020
# Gal : 40016
#  ===== 201654
# Gal : 40284
# Gal : 40300
#  ===== 201709
# Gal : 54852
#  ===== 201715
# Gal : 54921
#  ===== 201729
# Gal : 55250
#  ===== 201731
# Gal : 55299
#  ===== 201750
# Gal : 56106
#  ===== 201752
# Gal : 56140
#  ===== 201762
# Gal : 69516
#  ===== 201773
# Gal : 69903
#  ===== 201783
# Gal : 70319
# Gal : 70331
#  ===== 201799
# Gal : 71119
#  ===== 201850
# Gal : 85239
#  ===== 201856
# Gal : 610976
#  ===== 201883
# Gal : 98067
#  ===== 201922
# Gal : 99983
#  ===== 201927
# Gal : 100119
#  ===== 201999
# Gal : 124343
# Gal : 124345
# Gal : 124346
#  ===== 202044
# Gal : 130259
# Gal : 130272
# Gal : 130260
#  ===== 202057
# Gal : 130811
#  ===== 202062
# Gal : 131044
# Gal : 131043
# Gal : 131042
#  ===== 202072
# Gal : 131415
#  ===== 202088
# Gal : 132145
#  ===== 202089
# Gal : 132176
#  ===== 202113
# Gal : 177186
#  ===== 202120
# Gal : 137074
#  ===== 202149
# Gal : 138191
#  ===== 202156
# Gal : 138569
#  ===== 202160
# Gal : 138827
#  ===== 202175
# Gal : 143291
#  ===== 202344
# Gal : 172076
# Gal : 172073
#  ===== 202345
# Gal : 172072
# Gal : 172075
#  ===== 202385
# Gal : 177644
# Gal : 177643
#  ===== 202386
# Gal : 177665
#  ===== 202456
# Gal : 184550
#  ===== 202478
# Gal : 185593
# Gal : 185592
#  ===== 202502
# Gal : 186507
#  ===== 202749
# Gal : 534971
#  ===== 202771
# Gal : 535641
# Gal : 535642
#  ===== 202798
# Gal : 537031
#  ===== 202821
# Gal : 559398
#  ===== 202952
# Gal : 609948
# Gal : 609966
#  ===== 202972
# Gal : 610937
# Gal : 610938
#  ===== 202992
# Gal : 55100
#  ===== 203017
# Gal : 7001
#  ===== 203030
# Gal : 7104
#  ===== 203032
# Gal : 7139
#  ===== 203039
# Gal : 7203
#  ===== 203041
# Gal : 7209
#  ===== 203048
# Gal : 7289
#  ===== 203119
# Gal : 8277
#  ===== 203121
# Gal : 8299
# Gal : 8301
#  ===== 203122
# Gal : 8307
#  ===== 203167
# Gal : 8865
#  ===== 203173
# Gal : 8915
#  ===== 203179
# Gal : 8975
#  ===== 203228
# Gal : 21964
#  ===== 203302
# Gal : 22849
# Gal : 22836
#  ===== 203339
# Gal : 23319
#  ===== 203375
# Gal : 23751
#  ===== 203398
# Gal : 273493
#  ===== 203435
# Gal : 100083
#  ===== 203449
# Gal : 30396
#  ===== 203492
# Gal : 30820
#  ===== 203699
# Gal : 39512
#  ===== 203751
# Gal : 40120
#  ===== 203771
# Gal : 40403
#  ===== 203812
# Gal : 41007
#  ===== 203818
# Gal : 41050
#  ===== 203826
# Gal : 41237
#  ===== 203831
# Gal : 41274
# Gal : 41276
#  ===== 203850
# Gal : 53706
#  ===== 203914
# Gal : 54462
#  ===== 203930
# Gal : 54694
#  ===== 203950
# Gal : 560355
#  ===== 203954
# Gal : 55048
#  ===== 203965
# Gal : 55159
#  ===== 203966
# Gal : 55148
# Gal : 55149
#  ===== 203995
# Gal : 55373
#  ===== 204015
# Gal : 561091
#  ===== 204030
# Gal : 55713
#  ===== 204104
# Gal : 69512
#  ===== 204114
# Gal : 69604
#  ===== 204125
# Gal : 69716
# Gal : 69717
#  ===== 204137
# Gal : 69862
#  ===== 204149
# Gal : 69986
#  ===== 204169
# Gal : 70238
#  ===== 204191
# Gal : 70491
#  ===== 204223
# Gal : 70808
#  ===== 204248
# Gal : 71033
# Gal : 71034
#  ===== 204260
# Gal : 71196
#  ===== 204270
# Gal : 71310
#  ===== 204353
# Gal : 84335
#  ===== 204364
# Gal : 84461
#  ===== 204367
# Gal : 84517
#  ===== 204374
# Gal : 84610
#  ===== 204395
# Gal : 84982
#  ===== 204594
# Gal : 99116
#  ===== 204598
# Gal : 99120
#  ===== 204600
# Gal : 99151
#  ===== 204657
# Gal : 99931
#  ===== 204840
# Gal : 123854
# Gal : 123855
#  ===== 204845
# Gal : 123923
# Gal : 123924
#  ===== 204873
# Gal : 124341
#  ===== 204876
# Gal : 124380
#  ===== 204923
# Gal : 124966
#  ===== 204978
# Gal : 125631
#  ===== 205020
# Gal : 130061
# Gal : 130067
#  ===== 205035
# Gal : 130207
#  ===== 205096
# Gal : 178105
#  ===== 205099
# Gal : 130906
#  ===== 205114
# Gal : 131124
# Gal : 131130
#  ===== 205176
# Gal : 131936
#  ===== 205184
# Gal : 179180
#  ===== 205205
# Gal : 132289
# Gal : 132262
#  ===== 205224
# Gal : 132399
#  ===== 205289
# Gal : 136961
#  ===== 205296
# Gal : 136998
#  ===== 205378
# Gal : 138142
#  ===== 205401
# Gal : 138346
#  ===== 205527
# Gal : 143818
#  ===== 205547
# Gal : 144171
#  ===== 205553
# Gal : 144245
#  ===== 205591
# Gal : 144605
#  ===== 205598
# Gal : 144673
#  ===== 205639
# Gal : 145247
#  ===== 205651
# Gal : 145375
#  ===== 205652
# Gal : 145382
#  ===== 205661
# Gal : 145465
#  ===== 205722
# Gal : 164071
#  ===== 205916
# Gal : 170630
#  ===== 205928
# Gal : 170759
#  ===== 205949
# Gal : 171140
#  ===== 206004
# Gal : 171803
#  ===== 206026
# Gal : 172045
# Gal : 172046
#  ===== 206150
# Gal : 177424
#  ===== 206238
# Gal : 178886
#  ===== 206353
# Gal : 184577
#  ===== 206433
# Gal : 185455
#  ===== 206448
# Gal : 185654
#  ===== 206571
# Gal : 220069
#  ===== 206606
# Gal : 220511
#  ===== 206813
# Gal : 271591
#  ===== 206851
# Gal : 272043
#  ===== 206892
# Gal : 272637
#  ===== 206912
# Gal : 272975
#  ===== 207263
# Gal : 397453
#  ===== 207340
# Gal : 534943
#  ===== 207344
# Gal : 534980
#  ===== 207350
# Gal : 535088
#  ===== 207374
# Gal : 535457
#  ===== 207473
# Gal : 537036
# Gal : 537035
#  ===== 207477
# Gal : 537084
#  ===== 207632
# Gal : 560295
#  ===== 207663
# Gal : 560836
#  ===== 207675
# Gal : 560982
#  ===== 207677
# Gal : 561032
#  ===== 207721
# Gal : 561691
#  ===== 207731
# Gal : 561785
#  ===== 207867
# Gal : 584723
#  ===== 207903
# Gal : 585196
#  ===== 208009
# Gal : 609777
#  ===== 208040
# Gal : 610129
#  ===== 208062
# Gal : 610357
#  ===== 208075
# Gal : 610572
#  ===== 208096
# Gal : 610876
#  ===== 208103
# Gal : 610991
#  ===== 208106
# Gal : 611064
#  ===== 208110
# Gal : 611107
#  ===== 300001
# Gal : 250250
# Gal : 250251
# Gal : 250252
# Gal : 250255
# Gal : 250256
# Gal : 250257
# Gal : 250258
# Gal : 250259
# Gal : 250268
# Gal : 250269
# Gal : 250270
# Gal : 250247
# Gal : 250246
# Gal : 250226
# Gal : 250228
# Gal : 250237
# Gal : 250239
# Gal : 250241
# Gal : 250243
# Gal : 250245
# Gal : 250273
# Gal : 250378
# Gal : 250396
# Gal : 250464
# Gal : 261413
# Gal : 250276
# Gal : 250278
# Gal : 250292
# Gal : 250320
# Gal : 250325
# Gal : 250329
# Gal : 250331
# Gal : 250189
# Gal : 250184
# Gal : 250186
# Gal : 342073
# Gal : 342110
# Gal : 342114
# Gal : 342115
# Gal : 342120
# Gal : 342124
# Gal : 342147
# Gal : 250122
# Gal : 250132
# Gal : 319452
# Gal : 250179
# Gal : 250183
# Gal : 319373
# Gal : 319431
# Gal : 319411
# Gal : 319402
# Gal : 319404
# Gal : 319395
# Gal : 319398
#  ===== 300014
# Gal : 47254
#  ===== 300024
# Gal : 618943
# Gal : 78522
# Gal : 618942
# Gal : 618941
# Gal : 618938
# Gal : 618937
# Gal : 618931
# Gal : 618930
# Gal : 618929
# Gal : 618947
# Gal : 618912
# Gal : 618907
# Gal : 618905
# Gal : 618914
# Gal : 92773
#  ===== 300048
# Gal : 238219
# Gal : 238198
# Gal : 238282
# Gal : 238205
# Gal : 238212
# Gal : 238211
# Gal : 238213
# Gal : 238214
# Gal : 238217
# Gal : 238316
#  ===== 300052
# Gal : 79706
# Gal : 594961
# Gal : 594975
# Gal : 79688
# Gal : 594992
#  ===== 300072
# Gal : 227616
# Gal : 227617
#  ===== 300106
# Gal : 93807
#  ===== 300112
# Gal : 342699
# Gal : 342702
# Gal : 342697
# Gal : 251013
# Gal : 251020
# Gal : 251021
# Gal : 342686
# Gal : 342706
# Gal : 342714
# Gal : 342710
# Gal : 251024
# Gal : 342708
#  ===== 300118
# Gal : 568221
# Gal : 568243
# Gal : 568242
# Gal : 568222
# Gal : 568220
#  ===== 300120
# Gal : 618151
# Gal : 618142
# Gal : 618100
# Gal : 618131
# Gal : 618113
# Gal : 618138
# Gal : 618133
#  ===== 300134
# Gal : 296927
# Gal : 238453
# Gal : 319295
#  ===== 300149
# Gal : 569439
# Gal : 569418
#  ===== 300154
# Gal : 16526
# Gal : 16521
# Gal : 16561
# Gal : 16515
# Gal : 16514
# Gal : 16507
# Gal : 16525
#  ===== 300162
# Gal : 92000
# Gal : 91988
# Gal : 91989
# Gal : 91999
# Gal : 91963
# Gal : 91959
#  ===== 300170
# Gal : 251889
#  ===== 300177
# Gal : 492411
#  ===== 300194
# Gal : 62334
# Gal : 62336
# Gal : 62344
# Gal : 62361
# Gal : 62332
# Gal : 62319
#  ===== 300199
# Gal : 77705
#  ===== 300211
# Gal : 238499
#  ===== 300212
# Gal : 239090
# Gal : 239151
# Gal : 239106
# Gal : 297616
#  ===== 300219
# Gal : 319196
# Gal : 319058
# Gal : 319059
# Gal : 319137
# Gal : 319140
# Gal : 319067
#  ===== 300236
# Gal : 508665
# Gal : 508677
# Gal : 508678
# Gal : 508679
# Gal : 508705
#  ===== 300244
# Gal : 570214
# Gal : 570203
# Gal : 570207
#  ===== 300248
# Gal : 593807
# Gal : 593814
#  ===== 300256
# Gal : 544330
# Gal : 544328
#  ===== 300257
# Gal : 48740
# Gal : 48724
#  ===== 300268
# Gal : 91697
# Gal : 91689
# Gal : 91691
#  ===== 300283
# Gal : 250472
#  ===== 300289
# Gal : 262017
# Gal : 262013
# Gal : 262012
#  ===== 300377
# Gal : 78675
# Gal : 78660
# Gal : 78659
# Gal : 78668
#  ===== 300380
# Gal : 91582
#  ===== 300383
# Gal : 92778
# Gal : 92782
#  ===== 300401
# Gal : 238118
#  ===== 300439
# Gal : 298484
#  ===== 300446
# Gal : 320549
#  ===== 300453
# Gal : 361843
#  ===== 300499
# Gal : 47293
# Gal : 47295
# Gal : 567543
#  ===== 300520
# Gal : 15481
#  ===== 300527
# Gal : 496997
#  ===== 300528
# Gal : 37063
# Gal : 511864
#  ===== 300535
# Gal : 48377
#  ===== 300555
# Gal : 77345
#  ===== 300564
# Gal : 91961
# Gal : 91962
#  ===== 300567
# Gal : 92455
# Gal : 92434
#  ===== 300586
# Gal : 107277
# Gal : 107280
# Gal : 107278
# Gal : 16567
#  ===== 300593
# Gal : 228742
# Gal : 228708
#  ===== 300614
# Gal : 251073
# Gal : 251075
#  ===== 300732
# Gal : 511892
#  ===== 300739
# Gal : 544179
# Gal : 544209
#  ===== 300742
# Gal : 544954
#  ===== 300746
# Gal : 545454
#  ===== 300781
# Gal : 618663
# Gal : 618661
# Gal : 618662
# Gal : 618612
# Gal : 618605
#  ===== 300806
# Gal : 16022
#  ===== 300808
# Gal : 16166
# Gal : 92884
#  ===== 300831
# Gal : 48428
#  ===== 300860
# Gal : 63275
#  ===== 300889
# Gal : 78530
#  ===== 300892
# Gal : 78740
#  ===== 300922
# Gal : 106288
#  ===== 300941
# Gal : 227484
#  ===== 300967
# Gal : 238458
#  ===== 300979
# Gal : 239264
#  ===== 301028
# Gal : 261697
# Gal : 261718
#  ===== 301032
# Gal : 262301
# Gal : 262299
# Gal : 262291
#  ===== 301092
# Gal : 318840
#  ===== 301101
# Gal : 319526
#  ===== 301103
# Gal : 319651
# Gal : 319661
#  ===== 301111
# Gal : 320277
#  ===== 301135
# Gal : 343640
# Gal : 343639
# Gal : 343637
#  ===== 301146
# Gal : 361918
# Gal : 361920
# Gal : 361919
#  ===== 301214
# Gal : 487114
#  ===== 301231
# Gal : 492941
#  ===== 301239
# Gal : 493838
#  ===== 301242
# Gal : 497035
#  ===== 301258
# Gal : 508137
# Gal : 508132
# Gal : 508143
#  ===== 301269
# Gal : 508754
#  ===== 301284
# Gal : 511535
# Gal : 511532
#  ===== 301289
# Gal : 512312
#  ===== 301292
# Gal : 512552
# Gal : 512555
#  ===== 301315
# Gal : 544260
# Gal : 544259
#  ===== 301339
# Gal : 568050
#  ===== 301340
# Gal : 568130
#  ===== 301347
# Gal : 568545
#  ===== 301356
# Gal : 569139
#  ===== 301377
# Gal : 592430
# Gal : 592425
#  ===== 301388
# Gal : 592808
#  ===== 301390
# Gal : 593008
#  ===== 301435
# Gal : 619905
#  ===== 301455
# Gal : 15165
# Gal : 15166
#  ===== 301463
# Gal : 15522
#  ===== 301466
# Gal : 15664
# Gal : 15663
#  ===== 301486
# Gal : 16386
#  ===== 301495
# Gal : 107349
#  ===== 301527
# Gal : 543605
#  ===== 301542
# Gal : 48004
# Gal : 48010
#  ===== 301543
# Gal : 48013
#  ===== 301545
# Gal : 48053
# Gal : 48049
#  ===== 301560
# Gal : 48328
#  ===== 301579
# Gal : 48848
#  ===== 301597
# Gal : 49729
#  ===== 301625
# Gal : 62990
# Gal : 63018
#  ===== 301630
# Gal : 63210
#  ===== 301663
# Gal : 64085
#  ===== 301792
# Gal : 92431
# Gal : 92435
#  ===== 301797
# Gal : 92592
#  ===== 301798
# Gal : 92727
#  ===== 301875
# Gal : 107640
#  ===== 301890
# Gal : 227315
#  ===== 301909
# Gal : 228187
#  ===== 301935
# Gal : 229164
#  ===== 301961
# Gal : 238123
#  ===== 301969
# Gal : 238500
#  ===== 302003
# Gal : 298549
# Gal : 240021
#  ===== 302004
# Gal : 320940
# Gal : 320938
#  ===== 302039
# Gal : 250336
# Gal : 250337
# Gal : 342162
#  ===== 302046
# Gal : 250608
#  ===== 302050
# Gal : 250800
#  ===== 302063
# Gal : 251227
# Gal : 251225
#  ===== 302064
# Gal : 251268
# Gal : 251269
#  ===== 302091
# Gal : 261219
#  ===== 302102
# Gal : 261522
#  ===== 302200
# Gal : 296835
#  ===== 302244
# Gal : 298482
# Gal : 719185
#  ===== 302314
# Gal : 342019
#  ===== 302332
# Gal : 343005
# Gal : 343000
#  ===== 302536
# Gal : 492169
#  ===== 302540
# Gal : 492233
#  ===== 302548
# Gal : 492487
# Gal : 492486
#  ===== 302650
# Gal : 508671
# Gal : 508670
#  ===== 302715
# Gal : 513145
#  ===== 302735
# Gal : 544304
#  ===== 302745
# Gal : 544755
#  ===== 302783
# Gal : 546026
#  ===== 302865
# Gal : 592666
# Gal : 592665
#  ===== 302886
# Gal : 593674
#  ===== 302896
# Gal : 594078
# Gal : 594053
#  ===== 303022
# Gal : 15163
#  ===== 303032
# Gal : 15317
#  ===== 303047
# Gal : 15492
#  ===== 303049
# Gal : 15518
#  ===== 303162
# Gal : 17093
#  ===== 303177
# Gal : 17355
#  ===== 303193
# Gal : 28758
#  ===== 303202
# Gal : 106815
#  ===== 303237
# Gal : 47296
#  ===== 303297
# Gal : 48040
#  ===== 303444
# Gal : 49761
#  ===== 303467
# Gal : 62244
#  ===== 303475
# Gal : 62339
#  ===== 303556
# Gal : 693307
#  ===== 303733
# Gal : 77238
#  ===== 303880
# Gal : 79302
#  ===== 303995
# Gal : 92212
#  ===== 304097
# Gal : 93676
#  ===== 304255
# Gal : 107014
#  ===== 304267
# Gal : 107135
#  ===== 304285
# Gal : 107416
#  ===== 304572
# Gal : 238130
#  ===== 304581
# Gal : 238278
# Gal : 238276
#  ===== 304583
# Gal : 238325
#  ===== 304591
# Gal : 238411
# Gal : 238398
#  ===== 304684
# Gal : 239610
#  ===== 304712
# Gal : 240049
#  ===== 304806
# Gal : 250046
#  ===== 304830
# Gal : 250471
#  ===== 304836
# Gal : 250568
#  ===== 304859
# Gal : 250843
#  ===== 304968
# Gal : 252182
#  ===== 305035
# Gal : 261418
#  ===== 305045
# Gal : 261521
#  ===== 305046
# Gal : 261545
#  ===== 305085
# Gal : 262043
# Gal : 362963
#  ===== 305161
# Gal : 263071
#  ===== 305414
# Gal : 296636
#  ===== 305419
# Gal : 296743
# Gal : 296744
#  ===== 305466
# Gal : 297271
#  ===== 305569
# Gal : 298611
#  ===== 305581
# Gal : 298742
# Gal : 298741
#  ===== 305584
# Gal : 298791
# Gal : 298790
#  ===== 305641
# Gal : 319293
#  ===== 305720
# Gal : 320379
#  ===== 305745
# Gal : 320807
#  ===== 305754
# Gal : 320889
#  ===== 305837
# Gal : 341931
#  ===== 305858
# Gal : 342198
#  ===== 305859
# Gal : 342199
#  ===== 305910
# Gal : 343077
#  ===== 305966
# Gal : 343938
#  ===== 306017
# Gal : 362195
#  ===== 306113
# Gal : 363319
#  ===== 306160
# Gal : 364087
#  ===== 306326
# Gal : 514022
#  ===== 306596
# Gal : 492410
#  ===== 306606
# Gal : 492485
#  ===== 306626
# Gal : 492718
#  ===== 306628
# Gal : 492762
#  ===== 306641
# Gal : 492987
#  ===== 306698
# Gal : 493609
#  ===== 306709
# Gal : 493778
#  ===== 306883
# Gal : 508187
#  ===== 306979
# Gal : 509393
#  ===== 307019
# Gal : 511558
#  ===== 307030
# Gal : 511728
#  ===== 307317
# Gal : 545903
#  ===== 307363
# Gal : 567803
#  ===== 307374
# Gal : 567907
#  ===== 307424
# Gal : 568713
#  ===== 307487
# Gal : 569467
#  ===== 307566
# Gal : 592272
#  ===== 307567
# Gal : 592275
#  ===== 307569
# Gal : 592294
#  ===== 307579
# Gal : 592384
#  ===== 307619
# Gal : 592881
#  ===== 307622
# Gal : 592915
#  ===== 307647
# Gal : 593215
#  ===== 307735
# Gal : 594063
#  ===== 307827
# Gal : 617693
#  ===== 307854
# Gal : 617935
#  ===== 307925
# Gal : 619066
#  ===== 307938
# Gal : 619258
#  ===== 307954
# Gal : 619480
# Total number of Groups : 26194
# Non Empty Groups : 736
# Empty Groups 25458
# Group with Single Galaxy 477
