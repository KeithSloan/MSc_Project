# %%
from astropy.table import Table, join
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import pandas as pd


ForGroup = Table.read('../../GAMA_DATA/G3CFoFGroupv10.fits')
print(f"ForGroup : {len(ForGroup)}")
## Clean Data

GroupGal = Table.read('../../GAMA_DATA/G3CGalv10.fits')
# Clean data
GroupGal = GroupGal[GroupGal['GroupID'] > 0 ]
print(f"GroupGal : {len(GroupGal)}")

StellarMasses = Table.read('../../GAMA_DATA/StellarMassesv19.fits')
# Clean Data
#StellarMasses = StellarMasses[StellarMasses['uminusr'] > 0.001]
#StellarMasses = StellarMasses[StellarMasses['logmstar'] > 0.001]
#StellarMasses = StellarMasses[StellarMasses['metal'] > 0.001]


StellarMasses = StellarMasses[StellarMasses['uminusr'] > 0.01]
StellarMasses = StellarMasses[StellarMasses['logmstar'] > 0.01]
StellarMasses = StellarMasses[StellarMasses['metal'] > 0.01]
print(f"StellarMasses : {len(StellarMasses)}")

envClass = Table.read('../../GAMA_DATA/GalaxiesClassifiedv01.fits')

envMeasures = Table.read('../../GAMA_DATA/EnvironmentMeasuresv05.fits')
print(f"EnvMeasures : {len(envMeasures)}")
# Clean Data
envMeasures = envMeasures[envMeasures['SurfaceDensity'] < 50]
envMeasures = envMeasures[envMeasures['AGEDenParFlag'] == 0]
envMeasures = envMeasures[envMeasures['CountInCylFlag'] == 0]
envMeasures = envMeasures[envMeasures['CountInCyl'] > 0]


visualMorph = Table.read('../../GAMA_Data/VisualMorphologyv03.fits')
print(f"visualMorph : {len(visualMorph)}")
## Clean Data
visualMorph = visualMorph[visualMorph['ELLIPTICAL_CODE'] == 1]


DataLocalGroup = join(GroupGal,envMeasures,keys='CATAID',join_type='inner')
print(f"Join GroupGal & EnvMeasures {len(DataLocalGroup)}")
#print('GroupGal & EnvMeasures')
print(DataLocalGroup.colnames)

DataLocalGroup = join(DataLocalGroup,visualMorph,keys='CATAID',join_type='inner')
print(f"Join GroupGal & VisualMorph {len(DataLocalGroup)}")
#print('GroupGal & VisualMorph')
print(DataLocalGroup.colnames)

import math

# Sum uminsur, logmstar and metal over Local Group
DLG_Groups = DataLocalGroup.group_by('GroupID')
#print('DLG_Groups')
#print(DLG_Groups.colnames)
#GroupData = DLG_Groups['GroupID','uminusr','logmstar','metal'].groups.aggregate(np.sum)


GroupData = DLG_Groups['GroupID','CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar'].groups.aggregate(np.mean)
#print(GroupData)

GroupStdDev = DLG_Groups['GroupID','CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar'].groups.aggregate(np.std)
#print(GroupStdDev)


#print('GroupData')
#print(GroupData.colnames)
print('ForGroup')
print(ForGroup.colnames)

FinalData = join(ForGroup,GroupData,keys='GroupID',join_type='inner')
print('FinalData')
print(FinalData.colnames)


alphaVal = .3
binCount = 100

RErange = FinalData
#RErange = GroupData
                                                             
yfield = 'TotRmag'

fig = plt.figure(figsize=(10, 6), dpi=300)
fig.suptitle('Scatter - '+yfield+' versus Mean(Environments) for Elliptical Galaxies')
xfields = ['CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar']
y = RErange[yfield]
for i,xfield in enumerate(xfields,1) :
    ax = fig.add_subplot(1, len(xfields), i)
    i += 1           
    ax.set_ylabel(yfield)
    ax.set_xlabel('Mean('+xfield+')')
    #ax.set_ylim([-5,7])
    #ax.invert_yaxis()
    x = RErange[xfield]
    ax.scatter(x,y,alpha=alphaVal,label=xfield)        
#fig.legend(loc="upper right")
fig.tight_layout()
#fig.savefig('../../ChartsPlots/RedScatterEnvironments.png', dpi=300, bbox_inches='tight')                      
plt.show()

fig = plt.figure(figsize=(10, 8), dpi=300)
fig.suptitle('Density Plots - Group '+yfield+' versus Mean(Environments) for Elliptical Galaxies')
xfields = ['CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar']
#xfields = ['GalData.CountInCyl','GalData.DistanceTo5nn','GalData.SurfaceDensity','GalData.AGEDenPar']      
y = RErange[yfield]
ymin = min(y)
print(ymin)
ymax = max(y)
print(ymax)
for i,xfield in enumerate(xfields,1) :
    x = RErange[xfield]
    xmin = min(x)
    xmax = max(x)
    X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    ax = fig.add_subplot(1, len(xfields), i)
    ax.set_ylabel(yfield)
    ax.set_xlabel('Mean('+xfield+')')
    #ax.set_ylim([-6,7])
    #ax.invert_yaxis()
    values = np.vstack([x, y])
    kernel = stats.gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    #ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax])
    #ax.imshow(np.rot90(Z), cmap='PuBu',extent=[xmin, xmax, ymin, ymax])
    #ax.imshow(np.rot90(Z), cmap='PuBu')
    ax.contour(X, Y, Z)
    #ax.plot(x, y, 'k.', markersize=2)
    #ax.set_xlim([xmin, xmax])
    #ax.set_ylim([ymin, ymax])
    r, p = stats.pearsonr(x,y)
    print(f"Pearson Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    r, p = stats.spearmanr(x,y)
    print(f"Spearman Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    m, c, r, p, se = stats.linregress(x,y)
    print(f"Linear Regresion x: {xfield} y: {yfield} slope : {m} Intercept {c} Correlation {r} Wald test {p} {se}")
    
plt.show()                            
#fig.legend(loc="upper right")
fig.tight_layout()
fig.savefig('../../ChartsPlots/GroupDensityTotRmag_Mean(Environments).png', dpi=300, bbox_inches='tight')
plt.show()


fig = plt.figure(figsize=(10, 4), dpi=300)
#fig.suptitle('Density Plots - Group '+yfield+' versus Log10(Mean(Environments Galaxies)  for Elliptical Galaxies')
#xfields = ['GalData.CountInCyl','GalData.DistanceTo5nn','GalData.SurfaceDensity','GalData.AGEDenPar']
xfields = ['CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar']     
y = RErange[yfield]
ymin = min(y)
ymax = max(y)
print(f" yfield {yfield} ymin {ymin} ymax {ymax}\n")
for i,xfield in enumerate(xfields,1) :
    x = RErange[xfield]
    xmin = min(x)
    xmax = max(x)
    print(f" xfield {xfield} xmin {xmin} xmax {xmax}")
    x = np.log10(RErange[xfield]+0.01)
    xmin = min(x)
    xmax = max(x)
    print(f" xfield {xfield} log values - xmin {xmin} xmax {xmax}")
    X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    ax = fig.add_subplot(1, len(xfields), i)
    ax.set_ylabel(yfield)
    ax.set_xlabel('Log10(Mean('+xfield+'))')
    #ax.set_ylim([-6,7.5])
    #ax.invert_yaxis()
    values = np.vstack([x, y])
    kernel = stats.gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    #ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax])
    #ax.imshow(np.rot90(Z), cmap='PuBu',extent=[xmin, xmax, ymin, ymax])
    
    #ax.imshow(np.rot90(Z), cmap='PuBu')
    ax.contour(X, Y, Z)  
    #ax.plot(x, y, 'k.', markersize=2)
    
    #ax.set_xlim([xmin, xmax])
    #ax.set_ylim([ymin, ymax])
    r, p = stats.spearmanr(x,y)
    print(f"Log Pearson Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    m, c, r, p, se = stats.linregress(x,y)
    print(f"Log Spearman Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    r, p = stats.pearsonr(x,y)
    print(f"Log Linear Regresion x: {xfield} y: {yfield} slope : {m} Intercept {c} Correlation {r} Wald test {p} {se}")
#fig.legend(loc="upper right")
fig.tight_layout()
fig.savefig('../../ChartsPlots/TotRmag_Log10_Mean_Environments.png', dpi=300, bbox_inches='tight')
plt.show()


fig = plt.figure(figsize=(10, 4), dpi=300)
fig.suptitle('Density Plots - Group StdDev versus Log(Mean(Environments Galaxies)  for Elliptical Galaxies')
#xfields = ['GalData.CountInCyl','GalData.DistanceTo5nn','GalData.SurfaceDensity','GalData.AGEDenPar']
xfields = ['CountInCyl','DistanceTo5nn','SurfaceDensity','AGEDenPar']     


for i,xfield in enumerate(xfields,1) :
    y = GroupStdDev[xfield]
    ymin = min(y)
    ymax = max(y)
    print(f" std {xfield} ymin {ymin} ymax {ymax}\n")
    x = RErange[xfield]
    xmin = min(x)
    xmax = max(x)
    print(f" xfield {xfield} xmin {xmin} xmax {xmax}")
    x = np.log(RErange[xfield]+0.01)
    xmin = min(x)
    xmax = max(x)
    print(f" xfield {xfield} log values - xmin {xmin} xmax {xmax}")
    X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    ax = fig.add_subplot(1, len(xfields), i)
    ax.set_ylabel('StdDev('+xfield+'))')
    ax.set_xlabel('Mean('+xfield+'))')
    ax.set_ylim([0,ymax*0.2])
    #ax.invert_yaxis()
    values = np.vstack([x, y])
    kernel = stats.gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    #ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax])
    #ax.imshow(np.rot90(Z), cmap='PuBu',extent=[xmin, xmax, ymin, ymax])
    
    #ax.imshow(np.rot90(Z), cmap='PuBu')
    ax.contour(X, Y, Z)  
    #ax.plot(x, y, 'k.', markersize=2)
    
    #ax.set_xlim([xmin, xmax])
    #ax.set_ylim([ymin, ymax])
    r, p = stats.spearmanr(x,y)
    print(f"Log Pearson Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    m, c, r, p, se = stats.linregress(x,y)
    print(f"Log Spearman Correlation x: {xfield} y: {yfield} Correlation : {r} T-Test : {p}")
    r, p = stats.pearsonr(x,y)
    print(f"Log Linear Regresion x: {xfield} y: {yfield} slope : {m} Intercept {c} Correlation {r} Wald test {p} {se}")
#fig.legend(loc="upper right")
fig.tight_layout()
fig.savefig('../../ChartsPlots/TotRmag_StdDev(Environments).png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ForGroup : 26194
# GroupGal : 83093
# StellarMasses : 114685
# EnvMeasures : 67996
# visualMorph : 38795
# Join GroupGal & EnvMeasures 24217
# ['CATAID', 'RA_1', 'Dec', 'Z', 'Rpetro', 'DM_100_25_75', 'SURVEY_CODE', 'SigErr', 'GroupID', 'RankIterCen', 'SepIterCen', 'CoSepIterCen', 'AngSepIterCen', 'RankBCG', 'SepBCG', 'CoSepBCG', 'AngSepBCG', 'RankCen', 'SepCen', 'CoSepCen', 'AngSepCen', 'RA_2', 'DEC', 'Z_TONRY', 'nQ', 'M_r', 'DistanceToEdge', 'Completeness', 'DistanceTo5nn', 'SurfaceDensity', 'SurfaceDensityErr', 'SurfaceDensityFlag', 'CountInCyl', 'CountInCylErr', 'CountInCylFlag', 'AGEDenPar', 'AGEErr', 'AGEScale', 'AGEDenParFlag']
# Join GroupGal & VisualMorph 1345
# ['CATAID', 'RA_1', 'Dec', 'Z', 'Rpetro', 'DM_100_25_75', 'SURVEY_CODE', 'SigErr', 'GroupID', 'RankIterCen', 'SepIterCen', 'CoSepIterCen', 'AngSepIterCen', 'RankBCG', 'SepBCG', 'CoSepBCG', 'AngSepBCG', 'RankCen', 'SepCen', 'CoSepCen', 'AngSepCen', 'RA_2', 'DEC', 'Z_TONRY', 'nQ', 'M_r', 'DistanceToEdge', 'Completeness', 'DistanceTo5nn', 'SurfaceDensity', 'SurfaceDensityErr', 'SurfaceDensityFlag', 'CountInCyl', 'CountInCylErr', 'CountInCylFlag', 'AGEDenPar', 'AGEErr', 'AGEScale', 'AGEDenParFlag', 'ELLIPTICAL', 'ELLIPTICAL_CODE', 'HUBBLE_TYPE_SPD', 'HUBBLE_TYPE_SPD_CODE', 'HUBBLE_TYPE_LSK', 'HUBBLE_TYPE_LSK_CODE', 'HUBBLE_TYPE_ASGR', 'HUBBLE_TYPE_ASGR_CODE', 'HUBBLE_TYPE', 'HUBBLE_TYPE_CODE', 'ASGR_DISTURBED', 'ASGR_NORMAL', 'ASGR_UNSURE', 'ASGR_CLASSIFIERS', 'ASGR_PROBDIST', 'P_EL', 'P_CS', 'P_EL_DEBIASED', 'P_CS_DEBIASED', 'URL_IMG']
# ForGroup
# ['GroupID', 'Nfof', 'IterCenCATAID', 'IterCenRA', 'IterCenDec', 'IterCenZ', 'Zfof', 'Rad50', 'Rad1Sig', 'Rad100', 'RelDen', 'Zcomp', 'GroupEdge', 'VelDisp', 'VelDispRaw', 'VelErr', 'TotRmag', 'TotFluxProxy', 'MassProxy', 'BCGCATAID', 'BCGRA', 'BCGDec', 'Rgap', 'CenRA', 'CenDec', 'RadKurt', 'AxAng', 'AxRat', 'SymKS', 'VelSkew', 'VelKurt', 'Modality', 'LinkTot', 'LinkStrenProj', 'LinkStrenRad', 'LinkStrenComb', 'MassA', 'MassAfunc', 'LumB', 'LumBfunc', 'd3vol', 'd3area', 'd2radec', 'd2raz', 'd2decz', 'distortcirc', 'distortellip', 'distortsph', 'URL_IMG']
# FinalData
# ['GroupID', 'Nfof', 'IterCenCATAID', 'IterCenRA', 'IterCenDec', 'IterCenZ', 'Zfof', 'Rad50', 'Rad1Sig', 'Rad100', 'RelDen', 'Zcomp', 'GroupEdge', 'VelDisp', 'VelDispRaw', 'VelErr', 'TotRmag', 'TotFluxProxy', 'MassProxy', 'BCGCATAID', 'BCGRA', 'BCGDec', 'Rgap', 'CenRA', 'CenDec', 'RadKurt', 'AxAng', 'AxRat', 'SymKS', 'VelSkew', 'VelKurt', 'Modality', 'LinkTot', 'LinkStrenProj', 'LinkStrenRad', 'LinkStrenComb', 'MassA', 'MassAfunc', 'LumB', 'LumBfunc', 'd3vol', 'd3area', 'd2radec', 'd2raz', 'd2decz', 'distortcirc', 'distortellip', 'distortsph', 'URL_IMG', 'CountInCyl', 'DistanceTo5nn', 'SurfaceDensity', 'AGEDenPar']
# -24.846533
# -18.25309
# Pearson Correlation x: CountInCyl y: TotRmag Correlation : -0.4103037509125078 T-Test : 1.1291270182633934e-28
# Spearman Correlation x: CountInCyl y: TotRmag Correlation : -0.35275905596402096 T-Test : 4.006665510948286e-21
# Linear Regresion x: CountInCyl y: TotRmag slope : -0.13390288411536375 Intercept -20.604661931056096 Correlation -0.4103037509125077 Wald test 1.1291270182639638e-28 0.011497874286409337
# Pearson Correlation x: DistanceTo5nn y: TotRmag Correlation : 0.2810608682647352 T-Test : 1.1493142262428087e-13
# Spearman Correlation x: DistanceTo5nn y: TotRmag Correlation : 0.3258578583210432 T-Test : 4.3517207765444646e-18
# Linear Regresion x: DistanceTo5nn y: TotRmag slope : 0.21460947162099936 Intercept -21.501263355314492 Correlation 0.2810608682647352 Wald test 1.1493142262432598e-13 0.028310141785123567
# Pearson Correlation x: SurfaceDensity y: TotRmag Correlation : -0.4451422031639354 T-Test : 5.111844091337926e-34
# Spearman Correlation x: SurfaceDensity y: TotRmag Correlation : -0.33891763791924534 T-Test : 1.5920665601448372e-19
# Linear Regresion x: SurfaceDensity y: TotRmag slope : -0.13572613630661776 Intercept -20.851009001053924 Correlation -0.4451422031639352 Wald test 5.111844091340672e-34 0.010548080914082096
# Pearson Correlation x: AGEDenPar y: TotRmag Correlation : -0.20238392597332266 T-Test : 1.213330146986587e-07
# Spearman Correlation x: AGEDenPar y: TotRmag Correlation : -0.2562198946985873 T-Test : 1.5570271338932114e-11
# Linear Regresion x: AGEDenPar y: TotRmag slope : -0.18886339554728715 Intercept -20.876828583022224 Correlation -0.2023839259733225 Wald test 1.2133301469871448e-07 0.035306356772775285
#  yfield TotRmag ymin -24.846532821655273 ymax -18.253089904785156
#
#  xfield CountInCyl xmin 1.0 xmax 20.030093170875727
#  xfield CountInCyl log values - xmin 0.004321373782642578 xmax 1.3018997363320914
# Log Pearson Correlation x: CountInCyl y: TotRmag Correlation : -0.35275905596402096 T-Test : 4.006665510948286e-21
# Log Spearman Correlation x: CountInCyl y: TotRmag Correlation : -0.3801816712888027 T-Test : 1.5567880875367047e-24
# Log Linear Regresion x: CountInCyl y: TotRmag slope : -1.1522873465904258 Intercept -20.58862865226484 Correlation -0.38018167128880287 Wald test 1.556788087535805e-24 0.10830102106410186
#  xfield DistanceTo5nn xmin 0.22300000488758087 xmax 11.090999603271484
#  xfield DistanceTo5nn log values - xmin -0.6326440698638979 xmax 1.0453620871324931
# Log Pearson Correlation x: DistanceTo5nn y: TotRmag Correlation : 0.3258578583210432 T-Test : 4.3517207765444646e-18
# Log Spearman Correlation x: DistanceTo5nn y: TotRmag Correlation : 0.36952797030706463 T-Test : 3.6008345115180626e-23
# Log Linear Regresion x: DistanceTo5nn y: TotRmag slope : 1.2903517094663666 Intercept -21.33775993427494 Correlation 0.3695279703070646 Wald test 3.6008345115163276e-23 0.12535502531044165
#  xfield SurfaceDensity xmin 0.004999999888241291 xmax 32.095001220703125
#  xfield SurfaceDensity log values - xmin -1.8239087441800648 xmax 1.50657269076535
# Log Pearson Correlation x: SurfaceDensity y: TotRmag Correlation : -0.33891763791924534 T-Test : 1.5920665601448372e-19
# Log Spearman Correlation x: SurfaceDensity y: TotRmag Correlation : -0.38537891713391975 T-Test : 3.222495565969988e-25
# Log Linear Regresion x: SurfaceDensity y: TotRmag slope : -0.6389167488643501 Intercept -21.188048851236783 Correlation -0.3853789171339199 Wald test 3.22249556596834e-25 0.05910264722109587
#  xfield AGEDenPar xmin 0.03099999949336052 xmax 9.105999946594238
#  xfield AGEDenPar log values - xmin -1.3872161486468677 xmax 0.9598043139640392
# Log Pearson Correlation x: AGEDenPar y: TotRmag Correlation : -0.2562198946985873 T-Test : 1.5570271338932114e-11
# Log Spearman Correlation x: AGEDenPar y: TotRmag Correlation : -0.2545412161692229 T-Test : 2.1304851674141474e-11
# Log Linear Regresion x: AGEDenPar y: TotRmag slope : -0.702269851288884 Intercept -21.14665935764088 Correlation -0.2545412161692229 Wald test 2.130485167413083e-11 0.10307724288012664
#  std CountInCyl ymin 0.0 ymax 8.004168277137014
#
#  xfield CountInCyl xmin 1.0 xmax 20.030093170875727
#  xfield CountInCyl log values - xmin 0.009950330853168092 xmax 2.997734925451152
# Log Pearson Correlation x: CountInCyl y: TotRmag Correlation : 0.4402368180559181 T-Test : 3.156575036109643e-33
# Log Spearman Correlation x: CountInCyl y: TotRmag Correlation : 0.4541953636440387 T-Test : 1.6411108700132048e-35
# Log Linear Regresion x: CountInCyl y: TotRmag slope : 0.37922241342091223 Intercept -0.13559118829759084 Correlation 0.45419536364403956 Wald test 1.6411108700118396e-35 0.028737162767363277
#  std DistanceTo5nn ymin 0.0 ymax 1.1369999647140565
#
#  xfield DistanceTo5nn xmin 0.22300000488758087 xmax 11.090999603271484
#  xfield DistanceTo5nn log values - xmin -1.4567168044396948 xmax 2.4070351586124215
# Log Pearson Correlation x: DistanceTo5nn y: TotRmag Correlation : -0.2688064619551293 T-Test : 1.3792840196663516e-12
# Log Spearman Correlation x: DistanceTo5nn y: TotRmag Correlation : -0.09791618726884875 T-Test : 0.011096113666589172
# Log Linear Regresion x: DistanceTo5nn y: TotRmag slope : -0.0158362977869161 Intercept 0.05374945521334421 Correlation -0.09791618726884864 Wald test 0.011096113666584502 0.006218273259823094
#  std SurfaceDensity ymin 0.0 ymax 12.771155600406647
#
#  xfield SurfaceDensity xmin 0.004999999888241291 xmax 32.095001220703125
#  xfield SurfaceDensity log values - xmin -4.199705085330508 xmax 3.469011819268223
# Log Pearson Correlation x: SurfaceDensity y: TotRmag Correlation : 0.4339452881021755 T-Test : 3.1228067441922624e-32
# Log Spearman Correlation x: SurfaceDensity y: TotRmag Correlation : 0.5142580243606681 T-Test : 1.2263910821033545e-46
# Log Linear Regresion x: SurfaceDensity y: TotRmag slope : 0.5569154281412417 Intercept 0.6284394384627526 Correlation 0.5142580243606684 Wald test 1.2263910821026589e-46 0.035881742908216795
#  std AGEDenPar ymin 0.0 ymax 2.826447162069357
#
#  xfield AGEDenPar xmin 0.03099999949336052 xmax 9.105999946594238
#  xfield AGEDenPar log values - xmin -3.1941832246348896 xmax 2.2100311055249735
# Log Pearson Correlation x: AGEDenPar y: TotRmag Correlation : 0.2904066999006184 T-Test : 1.5870046503990122e-14
# Log Spearman Correlation x: AGEDenPar y: TotRmag Correlation : 0.37724335582234936 T-Test : 3.74577009370452e-24
# Log Linear Regresion x: AGEDenPar y: TotRmag slope : 0.13528509847055797 Intercept 0.14720574386810525 Correlation 0.37724335582234997 Wald test 3.7457700937021256e-24 0.012830851807151857
