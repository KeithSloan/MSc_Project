# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.table import Table, join
ellipticalMasses = Table.read('GAMA_Data/EllipticalMasses.fits')
redEllipticalsL = ellipticalMasses[ellipticalMasses['uminusr'] > 1.8]
redEllipticals  = redEllipticalsL[redEllipticalsL['uminusr'] < 2.8]

redEllipticals.write('GAMA_Data/redElliptical.fits', format='fits',overwrite=True)

rows = len(ellipticalMasses)
print(rows)
x = np.arange(0, rows, 1)
y = ellipticalByRedness['uminusr']
yerr = ellipticalByRedness['deluminusr']

#plt.figure()
plt.errorbar(x, y, xerr=None, yerr=yerr)
plt.title("Plot of Redness (uminusr) of Elliptical Galaxies")

rows = len(redEllipticals)
print(rows)
x = np.arange(0, rows, 1)

y = redEllipticals['uminusr']
yerr = redEllipticals['deluminusr']

plt.errorbar(x,y, err=None, yerr=yerr)
plt.title("Plot of Redness (uminusr) of Red Elliptical Galaxies")
# Out:
# 2894
# 2560
# Text(0.5, 1.0, 'Plot of Redness (uminusr) of Red Elliptical Galaxies')
