# %%
from astropy.table import Table, join
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
from scipy import stats

RawMassEClassEmeasure = Table.read('../../GAMA_Data/EMassEClassEmeasure.fits')
#print(RawMassEClassEmeasure.colnames)
# CLEAN DATA
#REMassEClassEmeasure = RawMassEClassEmeasure[RawMassEClassEmeasure['CountInCyl']> -500]
RErange = RawMassEClassEmeasure[RawMassEClassEmeasure['CountInCyl']> -500]
print(RErange.colnames)
RErange = RErange[RErange['SurfaceDensityFlag'] == 0]
RErange = RErange[RErange['SurfaceDensity'] < 50]
RErange = RErange[RErange['AGEDenParFlag'] == 0]
RErange = RErange[RErange['CountInCylFlag'] == 0]
RErange = RErange[RErange['uminusr']> 0.001]
#RErange = RErange[RErange['uminusr']< 2.7]
#RErange = RErange[RErange['CountInCyl'] > 0]
RErange['CountInCyl'] = RErange['CountInCyl'] + 1

def testNorm(xfield, binCount) :
    
   print('Normal Test on '+xfield)
   fig = plt.figure(figsize=(12, 8), dpi=200)
   fig.suptitle('Histogram of '+xfield)
   ax1 = fig.add_subplot(1, 1, 1)
   
   ax1.hist(RErange[xfield].data, bins=binCount, density=True)
   plt.show() 
   r, p = stats.kstest(RErange[xfield], 'norm')
   print('kstest '+xfield+' norm : ' +str(r)+', '+str(p))
                                  
   r, p = stats.kstest(RErange[xfield], 'norm',alternative='greater')
   print('kstest '+xfield+' norm greater : ' +str(r)+', '+str(p))
                                  
   r, p = stats.stats.kstest(RErange[xfield], 'norm',alternative='less')
   print('kstest '+xfield+' norm less : ' +str(r)+', '+str(p))
    
   r, p = stats.shapiro(RErange[xfield])
   print('Shapiro '+xfield+' '+str(r)+','+str(p))

   s, cl, sl  = stats.anderson(RErange[xfield],'norm')
   print('Anderson '+xfield+' '+str(s)+','+str(cl)+', '+str(sl))
   print() 


def transformNone(xfield, binCount) :
   fig = plt.figure(figsize=(12, 8), dpi=200)
   ax1 = fig.add_subplot(1, 2, 1)
   ax1.title.set_text('Histogram - '+xfield) 
   ax1.hist(RErange[xfield].data, bins=binCount, density=True)
   #ret = stats.boxcox(RErange[xfield],lamda,alpha)
   transdata, lamda = stats.boxcox(RErange[xfield])
   ax2 = fig.add_subplot(1, 2, 2)
   ax2.title.set_text('Transformed - '+xfield)
   ax2.hist(transdata, bins=binCount, density=True)
   print(' Determined Lamda value : '+xfield+' : '+str(lamda))
   r, p = stats.pearsonr(RErange['uminusr'], RErange[xfield])
   print('Transform None - Pearson test uminusr versus '+xfield+' '+str(r)+', '+str(p))
   return transdata

def transformLamda(xfield, binCount, lamda) :
   fig = plt.figure(figsize=(12, 8), dpi=200)
   ax1 = fig.add_subplot(1, 2, 1)
   ax1.title.set_text('Histogram - '+xfield) 
   ax1.hist(RErange[xfield].data, bins=binCount, density=True)
   #ret = stats.boxcox(RErange[xfield],lamda,alpha)
   transdata = stats.boxcox(RErange[xfield],lamda)
   ax2 = fig.add_subplot(1, 2, 2)
   ax2.title.set_text('Transformed - '+xfield+' Lamda='+str(lamda))
   ax2.hist(transdata, bins=binCount, density=True)
   print(' Determined Lamda value : '+xfield+' : '+str(lamda))
   r, p = stats.pearsonr(RErange['uminusr'], RErange[xfield])
   print('Transform Lamda - Pearson test uminusr versus '+xfield+' '+str(r)+', '+str(p))    

def transformLog(xfield, binCount) :
   fig = plt.figure(figsize=(12, 8), dpi=200)
   ax1 = fig.add_subplot(1, 2, 1)
   ax1.title.set_text('Histogram - '+xfield) 
   ax1.hist(RErange[xfield].data, bins=binCount, density=True)
   #ret = stats.boxcox(RErange[xfield],lamda,alpha)
   transdata = np.log(RErange[xfield])
   ax2 = fig.add_subplot(1, 2, 2)
   ax2.title.set_text('Log transformation - '+xfield) 
   ax2.hist(transdata, bins=binCount, density=True)
   r, p = stats.pearsonr(RErange['uminusr'], RErange[xfield])
   print('Transform Log - Pearson test uminusr versus '+xfield+' '+str(r)+', '+str(p))


def spearmanTest(xfield) :
    print('Spearmen test : '+xfield)
    print(stats.spearmanr(RErange['uminusr'],RErange[xfield]))
    
def kendallTest(xfield) :
    print('Kendall Tau Test : '+xfield)
    print(stats.kendalltau(RErange['uminusr'],RErange[xfield]))
    
testNorm('uminusr',80)
testNorm('CountInCyl',35)
testNorm('DistanceTo5nn',80)
testNorm('SurfaceDensity',100)
testNorm('AGEDenPar',100)

transformLamda('CountInCyl', 35, 0.7)
transformLog('CountInCyl', 10)

plt.show()

T_DistanceTo5nn = transformNone('DistanceTo5nn',80)
T_uminusr = transformNone('uminusr',80)
r, p = stats.pearsonr(T_uminusr,T_DistanceTo5nn)


for i in ['DistanceTo5nn','CountInCyl','SurfaceDensity','AGEDenPar'] :                      
    spearmanTest(i)
    kendallTest(i)
# Out:
# ['CATAID', 'ELLIPTICAL', 'ELLIPTICAL_CODE', 'HUBBLE_TYPE_SPD', 'HUBBLE_TYPE_SPD_CODE', 'HUBBLE_TYPE_LSK', 'HUBBLE_TYPE_LSK_CODE', 'HUBBLE_TYPE_ASGR', 'HUBBLE_TYPE_ASGR_CODE', 'HUBBLE_TYPE', 'HUBBLE_TYPE_CODE', 'ASGR_DISTURBED', 'ASGR_NORMAL', 'ASGR_UNSURE', 'ASGR_CLASSIFIERS', 'ASGR_PROBDIST', 'P_EL', 'P_CS', 'P_EL_DEBIASED', 'P_CS_DEBIASED', 'URL_IMG', 'Z_1', 'nQ_1', 'SURVEY_CODE', 'SURVEY_CLASS', 'Z_TONRY_1', 'fluxscale', 'zmax_19p8', 'zmax_19p4', 'zmax_19p0', 'zmax_17p8', 'nbands', 'S2N', 'PPP', 'logmstar', 'dellogmstar', 'logmoverl_i', 'dellogmoverl_i', 'logage', 'dellogage', 'logtau', 'dellogtau', 'logmintsfh', 'dellogmintsfh', 'logmremnants', 'dellogmremnants', 'metal', 'delmetal', 'extBV', 'delextBV', 'logLWage', 'dellogLWage', 'gminusi', 'delgminusi', 'uminusr', 'deluminusr', 'gminusi_stars', 'uminusr_stars', 'C_logM_ur', 'C_logM_gi', 'C_logM_eBV', 'fitphot_u', 'delfitphot_u', 'absmag_u', 'delabsmag_u', 'absmag_u_stars', 'fitphot_g', 'delfitphot_g', 'absmag_g', 'delabsmag_g', 'absmag_g_stars', 'fitphot_r', 'delfitphot_r', 'absmag_r', 'delabsmag_r', 'absmag_r_stars', 'fitphot_i', 'delfitphot_i', 'absmag_i', 'delabsmag_i', 'absmag_i_stars', 'fitphot_z', 'delfitphot_z', 'absmag_z', 'delabsmag_z', 'absmag_z_stars', 'fitphot_X', 'delfitphot_X', 'absmag_X', 'delabsmag_X', 'absmag_X_stars', 'fitphot_Y', 'delfitphot_Y', 'absmag_Y', 'delabsmag_Y', 'absmag_Y_stars', 'fitphot_J', 'delfitphot_J', 'absmag_J', 'delabsmag_J', 'absmag_J_stars', 'fitphot_H', 'delfitphot_H', 'absmag_H', 'delabsmag_H', 'absmag_H_stars', 'fitphot_K', 'delfitphot_K', 'absmag_K', 'delabsmag_K', 'absmag_K_stars', 'URL_PNG', 'RA_1', 'DEC_1', 'Z_TONRY_2', 'nQ_2', 'M_r', 'DistanceToEdge', 'Completeness', 'DistanceTo5nn', 'SurfaceDensity', 'SurfaceDensityErr', 'SurfaceDensityFlag', 'CountInCyl', 'CountInCylErr', 'CountInCylFlag', 'AGEDenPar', 'AGEErr', 'AGEScale', 'AGEDenParFlag', 'RA_2', 'DEC_2', 'Z_2', 'NQ', 'GeoS4', 'GeoS10']
# Normal Test on uminusr
# kstest uminusr norm : 0.9127587600406205, 0.0
# kstest uminusr norm greater : 0.002381614147061173, 0.9753214630899972
# kstest uminusr norm less : 0.9127587600406205, 0.0
# Shapiro uminusr 0.970382571220398,3.264082808350377e-20
# Anderson uminusr 16.613927457114187,[0.575 0.655 0.785 0.916 1.09 ], [15.  10.   5.   2.5  1. ]
#
# Normal Test on CountInCyl
# kstest CountInCyl norm : 0.8413447460685429, 0.0
# kstest CountInCyl norm greater : 0.0, 1.0
# kstest CountInCyl norm less : 0.8413447460685429, 0.0
# Shapiro CountInCyl 0.7872155904769897,1.401298464324817e-45
# Anderson CountInCyl 129.39187965633982,[0.575 0.655 0.785 0.916 1.09 ], [15.  10.   5.   2.5  1. ]
#
# Normal Test on DistanceTo5nn
# kstest DistanceTo5nn norm : 0.5874829761575442, 0.0
# kstest DistanceTo5nn norm greater : 0.0, 1.0
# kstest DistanceTo5nn norm less : 0.5874829761575442, 0.0
# Shapiro DistanceTo5nn 0.9010786414146423,1.4371575566054055e-34
# Anderson DistanceTo5nn 50.293690545042864,[0.575 0.655 0.785 0.916 1.09 ], [15.  10.   5.   2.5  1. ]
#
# Normal Test on SurfaceDensity
# kstest SurfaceDensity norm : 0.5105982424209289, 0.0
# kstest SurfaceDensity norm greater : 0.0, 1.0
# kstest SurfaceDensity norm less : 0.5105982424209289, 0.0
# Shapiro SurfaceDensity 0.5268343687057495,0.0
# Anderson SurfaceDensity 328.96934591834906,[0.575 0.655 0.785 0.916 1.09 ], [15.  10.   5.   2.5  1. ]
#
# Normal Test on AGEDenPar
# kstest AGEDenPar norm : 0.5011968250563696, 0.0
# kstest AGEDenPar norm greater : 0.0, 1.0
# kstest AGEDenPar norm less : 0.5011968250563696, 0.0
# Shapiro AGEDenPar 0.7549655437469482,0.0
# Anderson AGEDenPar 141.04001155655988,[0.575 0.655 0.785 0.916 1.09 ], [15.  10.   5.   2.5  1. ]
#
#  Determined Lamda value : CountInCyl : 0.7
# Transform Lamda - Pearson test uminusr versus CountInCyl 0.10429914448051103, 2.0607302272586255e-06
# Transform Log - Pearson test uminusr versus CountInCyl 0.10429914448051103, 2.0607302272586255e-06
#  Determined Lamda value : DistanceTo5nn : 0.18558398627165526
# Transform None - Pearson test uminusr versus DistanceTo5nn -0.1340197719613556, 9.894013558069116e-10
#  Determined Lamda value : uminusr : 2.854915731964936
# Transform None - Pearson test uminusr versus uminusr 1.0, 0.0
# Spearmen test : DistanceTo5nn
# SpearmanrResult(correlation=-0.12937499873577613, pvalue=3.6908381828816373e-09)
# Kendall Tau Test : DistanceTo5nn
# KendalltauResult(correlation=-0.08622042034114605, pvalue=4.399443251494964e-09)
# Spearmen test : CountInCyl
# SpearmanrResult(correlation=0.1232657379614013, pvalue=1.9452550093485175e-08)
# Kendall Tau Test : CountInCyl
# KendalltauResult(correlation=0.08474002194603529, pvalue=2.4868848606136963e-08)
# Spearmen test : SurfaceDensity
# SpearmanrResult(correlation=0.12908035436268145, pvalue=4.0061264958508325e-09)
# Kendall Tau Test : SurfaceDensity
# KendalltauResult(correlation=0.08606150694665468, pvalue=4.714690627914911e-09)
# Spearmen test : AGEDenPar
# SpearmanrResult(correlation=0.1016619548597064, pvalue=3.7152919416017747e-06)
# Kendall Tau Test : AGEDenPar
# KendalltauResult(correlation=0.06763101839596224, pvalue=4.167191085511722e-06)
