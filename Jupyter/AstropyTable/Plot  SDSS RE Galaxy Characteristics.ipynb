# %%
from astropy.table import Table, join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sdss_red_ellipticalMasses = Table.read('../../GAMA_Data/SDSS_REMassEClassEmeasure.fits')
print(sdss_red_ellipticalMasses.colnames)
print(len(sdss_red_ellipticalMasses))

##### Plot of Redness versus Log of Mass for Elliptical Galaxies
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of Redness versus Log of Mass for Elliptical Galaxies")
ax.set_xlabel('logmstar')
ax.set_ylabel('Redness (uminusr)')
x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['uminusr']
#xerr = sdss_red_ellipticalMasses['deluminusr']
#yerr = sdss_red_ellipticalMasses['dellogmstar']             
ax.scatter(x,y,alpha=alphaVal,label='uminusr')
fig.legend(loc="upper right")
plt.axis([7.5, 12.5, 0, 3])
plt.show()

##### Plot of Redness versus Redshift for Elliptical Galaxies
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of Redness versus Redshift for Elliptical Galaxies")
ax.set_xlabel('Redshift Z')
ax.set_ylabel('Redness (uminusr)')
x = sdss_red_ellipticalMasses['Z_1']
y = sdss_red_ellipticalMasses['uminusr']
ax.scatter(x,y,alpha=alphaVal,label='Redness')
fig.legend(loc="upper right")
plt.axis([0, 0.2, 0, 3])
plt.show()

##### Plot of LogMass versus Red Shift Z
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of LogMass versus Red Shift Z for Elliptical Galaxies")
ax.set_xlabel('Redshift Z')
ax.set_ylabel('Log Mass')
x = sdss_red_ellipticalMasses['Z_1']
y = sdss_red_ellipticalMasses['logmstar']
ax.scatter(x,y,alpha=alphaVal,label='logmstar')
fig.legend(loc="upper right")
plt.axis([0, 0.2, 7.5, 12])
plt.show()

##### Plot of Metal versus Redness (uminusr) for Elliptical Galaxies
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of Metal versus Redness (uminusr) for Elliptical Galaxies")
ax.set_xlabel('uminusr')
ax.set_ylabel('Metal')
x = sdss_red_ellipticalMasses['uminusr']
y = sdss_red_ellipticalMasses['metal']
plt.scatter(x,y,alpha=alphaVal,label='metal')
fig.legend(loc="upper right")
#plt.axis([0, 3, 0, 0.06])
plt.show()

##### Plot of Metal versus Log Mass for Elliptical Galaxies
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of Metal versus Log Mass for Elliptical Galaxies")
ax.set_xlabel('Logmstar')
ax.set_ylabel('Metal')
x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['metal']
plt.scatter(x,y,alpha=alphaVal,label='metal')
fig.legend(loc="upper right")
plt.axis([7.5, 12, 0, 0.03])
plt.show()

#### Plot of Metal versus Log Mass for Elliptical Galaxies
fig, ax = plt.subplots(1, 1, figsize=(12,8)) # make the figure with the size 10 x 8 inches
fig.suptitle("Plot of Redness versus Log Age for Elliptical Galaxies")
ax.set_xlabel('Logmstar')
ax.set_ylabel('uminusr')
x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['uminusr']
plt.scatter(x,y,alpha=alphaVal,label='uminusr')
fig.legend(loc="upper right")
plt.axis([7.5, 12, 0, 3])
plt.show()



x = sdss_red_ellipticalMasses['uminusr']
y = sdss_red_ellipticalMasses['DistanceTo5nn']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)

plt.title("Distance To 5nn versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 3, 0, 3])
plt.show()

x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['DistanceTo5nn']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Distance To 5nn versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([10, 14, 8.5, 10.5])
plt.show()

x = sdss_red_ellipticalMasses['uminusr']
y = sdss_red_ellipticalMasses['SurfaceDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Surface Density versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 6, 0, 8])
plt.show()

x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['SurfaceDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Surface Density versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
plt.show()

x = sdss_red_ellipticalMasses['uminusr']
y = sdss_red_ellipticalMasses['CountInCyl']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Count In Cylinder versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 6, 0, 8])
plt.show()

x = sdss_red_ellipticalMasses['logmstar']
y = sdss_red_ellipticalMasses['CountInCyl']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Count In Cylinder versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
plt.show()

#x = sdss_red_ellipticalMasses['uminusr']
#y = sdss_red_ellipticalMasses['AGEDensity']
#plt.scatter(x,y,alpha=0.05)
#plt.scatter(x,y)
#plt.title("AGE Density versus Redness (uminusr) for Elliptical Galaxies")
#plt.axis([0, 6, 0, 8])
#plt.show()

#x = sdss_red_ellipticalMasses['logmstar']
#y = sdss_red_ellipticalMasses['AGEDensity']
#plt.scatter(x,y,alpha=0.05)
#plt.scatter(x,y)
#plt.title("AGE Density versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
#plt.show()
# Out:
# ['CATAID', 'OBJID', 'RA_1', 'DEC_1', 'FLAGS', 'PRIMTARGET', 'TYPE', 'PSFMAG_R', 'FIBERMAG_R', 'FLAGS_R', 'EXTINCTION_R', 'PETRORAD_R', 'PETROR90_R', 'PETROR50_R', 'PETROMAG_G', 'PETROMAG_R', 'PETROMAG_I', 'MODELMAG_U', 'MODELMAG_G', 'MODELMAG_R', 'MODELMAG_I', 'MODELMAG_Z', 'STATUS', 'RUN', 'Z_1', 'nQ_1', 'SURVEY_CODE', 'SURVEY_CLASS', 'Z_TONRY_1', 'fluxscale', 'zmax_19p8', 'zmax_19p4', 'zmax_19p0', 'zmax_17p8', 'nbands', 'S2N', 'PPP', 'logmstar', 'dellogmstar', 'logmoverl_i', 'dellogmoverl_i', 'logage', 'dellogage', 'logtau', 'dellogtau', 'logmintsfh', 'dellogmintsfh', 'logmremnants', 'dellogmremnants', 'metal', 'delmetal', 'extBV', 'delextBV', 'logLWage', 'dellogLWage', 'gminusi', 'delgminusi', 'uminusr', 'deluminusr', 'gminusi_stars', 'uminusr_stars', 'C_logM_ur', 'C_logM_gi', 'C_logM_eBV', 'fitphot_u', 'delfitphot_u', 'absmag_u', 'delabsmag_u', 'absmag_u_stars', 'fitphot_g', 'delfitphot_g', 'absmag_g', 'delabsmag_g', 'absmag_g_stars', 'fitphot_r', 'delfitphot_r', 'absmag_r', 'del
# ...
