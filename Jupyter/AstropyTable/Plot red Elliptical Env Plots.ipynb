# %%
from astropy.table import Table, join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sdss_red_ellipticalMasses = Table.read('../../GAMA_Data/redElliptical.fits')

#print(sdss_red_ellipticalMasses.colnames)
rows = len(sdss_red_ellipticalMasses)
print(rows)
x = sdss_red_ellipticalMasses['uminusr_1']
y = sdss_red_ellipticalMasses['logmstar_2']
xerr = sdss_red_ellipticalMasses['deluminusr_1']
yerr = sdss_red_ellipticalMasses['dellogmstar_2']

#plt.figure()
#plt.errorbar(x, y, xerr=xerr, yerr=yerr)
#plt.errorbar(x, y, xerr=None, yerr=None, fmt='o')
plt.scatter(x,y,alpha=0.05)
plt.title("Plot of Log Mass versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 3, 0, 20])
plt.show()

x = sdss_red_ellipticalMasses['uminusr_1']
y = sdss_red_ellipticalMasses['Z_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Red Shift Z versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 3, 0, 0.8])
plt.show()

x = sdss_red_ellipticalMasses['logmstar_2']
y = sdss_red_ellipticalMasses['Z_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Red Shift Z versus Log Mass (logmstar) for Elliptical Galaxies")
plt.axis([10, 14, 0, 0.8])
plt.show()

x = sdss_red_ellipticalMasses['uminusr_1']
y = sdss_red_ellipticalMasses['metal_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Metal versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 3, 0, 0.06])
plt.show()

x = sdss_red_ellipticalMasses['logmstar_2']
y = sdss_red_ellipticalMasses['metal_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Metal versus Log Mass (logmstar) for Elliptical Galaxies")
plt.axis([10, 14, 0, 0.06])
plt.show()


x = sdss_red_ellipticalMasses['uminusr_1']
y = sdss_red_ellipticalMasses['logage_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Log Age versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 3, 8.5, 10.5])
plt.show()

x = sdss_red_ellipticalMasses['logmstar_2']
y = sdss_red_ellipticalMasses['logage_1']
plt.scatter(x,y,alpha=0.05)
plt.title("Log Age versus Log Mass (logmstar) for Elliptical Galaxies")
plt.axis([10, 14, 8.5, 10.5])
plt.show()

sdss_red_ellipticalEnvMeasures = Table.read('GAMA_Data/SDSS_Red_Elliptical_Env_Measures.fits')
#print(sdss_red_ellipticalEnvMeasures.colnames)

x = sdss_red_ellipticalEnvMeasures['uminusr_1']
y = sdss_red_ellipticalEnvMeasures['DistanceTo5nn']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)

plt.title("Distance To 5nn versus Redness (uminusr) for Elliptical Galaxies")
#plt.axis([0, 3, 8.5, 10.5])
plt.show()

x = sdss_red_ellipticalEnvMeasures['logmstar_2']
y = sdss_red_ellipticalEnvMeasures['DistanceTo5nn']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Distance To 5nn versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([10, 14, 8.5, 10.5])
plt.show()

x = sdss_red_ellipticalEnvMeasures['uminusr_1']
y = sdss_red_ellipticalEnvMeasures['SurfaceDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Surface Density versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 6, 0, 8])
plt.show()

x = sdss_red_ellipticalEnvMeasures['logmstar_2']
y = sdss_red_ellipticalEnvMeasures['SurfaceDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Surface Density versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
plt.show()

x = sdss_red_ellipticalEnvMeasures['uminusr_1']
y = sdss_red_ellipticalEnvMeasures['CountInCyl']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Count In Cylinder versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 6, 0, 8])
plt.show()

x = sdss_red_ellipticalEnvMeasures['logmstar_2']
y = sdss_red_ellipticalEnvMeasures['CountInCyl']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("Count In Cylinder versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
plt.show()

x = sdss_red_ellipticalEnvMeasures['uminusr_1']
y = sdss_red_ellipticalEnvMeasures['AGEDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("AGE Density versus Redness (uminusr) for Elliptical Galaxies")
plt.axis([0, 6, 0, 8])
plt.show()

x = sdss_red_ellipticalEnvMeasures['logmstar_2']
y = sdss_red_ellipticalEnvMeasures['AGEDensity']
#plt.scatter(x,y,alpha=0.05)
plt.scatter(x,y)
plt.title("AGE Density versus Log Mass (logmstar) for Elliptical Galaxies")
#plt.axis([0, 100, 0, 10])
plt.show()
# Out:
# 2649
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-ad29a62f988a> in <module>
#       9 rows = len(sdss_red_ellipticalMasses)
#      10 print(rows)
# ---> 11 x = sdss_red_ellipticalMasses['uminusr_1']
#      12 y = sdss_red_ellipticalMasses['logmstar_2']
#      13 xerr = sdss_red_ellipticalMasses['deluminusr_1']
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1652     def __getitem__(self, item):
#    1653         if isinstance(item, str):
# -> 1654             return self.columns[item]
#    1655         elif isinstance(item, (int, np.integer)):
#    1656             return self.Row(self, item)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
# ...
