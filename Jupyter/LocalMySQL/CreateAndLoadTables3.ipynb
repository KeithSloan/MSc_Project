# %%
# Create and Load Tables from GAMA Info
from __future__ import print_function
import re

#tableFiles = ['GAMA_Data/VisualMorphology/VisualMorphologyv01',
#              'GAMA_Data/StellarMasses/StellarMasses',
#              'GAMA_Data/StellarMasses/StellarMassesLambdar'
#             ]

#tableFiles = ['GAMA_Data/VisualMorphology/VisualMorphologyv01']

tableFiles = ['GAMA_Data/StellarMasses/StellarMasses']

#tableFiles = ['GAMA_Data/StellarMasses/StellarMassesLambdar']

import mysql.connector
from mysql.connector import errorcode

class switch(object):
    value = None
    def __new__(class_, value):
        class_.value = value
        return True

def case(*args):
    return any((arg == switch.value for arg in args))


def makeSQLrequest(cursor,request) :
    try:
        cursor.execute(request)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print('OK')
        
def makeSQLinsertRequest(cursor,add,request) :
    
    try:
        cursor.execute(add,request)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print('OK')
        
        
        
def createAndLoadTable(cnx,cursor,tableFile) :
    
    fd = open(tableFile,'r')
    fp = open(tableFile + '.par','r')
    #
    # Get Table Name
    #
    raw = fp.readline()
    line = re.split('; | ',raw)
    print(line)
    table = line[1].rstrip()
    print('Table : '+table)

    request = 'DROP TABLE '+table
    print(request)
    makeSQLrequest(cursor,request)

    request = 'CREATE TABLE `'+table+ '` ('
    # Create as Lists and convert to Tuple for SQL
    addFields = '(' 
    addValues = '('                                   
    #
    # Get field lengths of first line of data 
    #
    rawdata = fd.readline()
    tableData = rawdata.split()
    fieldLengths = []
    for j in tableData :
        fieldLengths.append(len(j))
    #
    # Check next n lines of Data
    #
    n = 50
    for i in range(n) :
        rawdata = fd.readline()
        tableData = rawdata.split()
        for j in range(len(tableData)) :
            if len(tableData[j]) > fieldLengths[j] :
                fieldLengths[j] = len(tableData[j]) 
    #
    #  Process pre information
    #
    keyCol = False
    fieldCount = 0
    for raw in fp :
        line = raw.split()
        print(line)
        if  raw[0] != '#' :
            column = line[0]
            if keyCol == False :
                keyCol = column 
            print('Column : ' + column)
            request += " `"+column+"` "
            addFields += column+", " 
            addValues += '%s, '
            fieldCount = fieldCount + 1
            num = int(line[1])
            print('num : ' + str(num))
            lf = fieldLengths[num-1]
            f3 = line[3]
            if ';' in f3 :
                print('Found semi colon')
                m = f3.index(';')
                f3 = f3[:m]
            print(f3)    
            if f3 == 'meta.id' :
                print('Integer')
                request += ' int(8),' 
            elif f3 == 'meta.code.class' or f3 == 'meta.ref.url' :
                request += ' text,'
            elif f3 == 'photo.color' or f3 == 'stat.error':
                request += ' decimal,'
            elif line[2] == 'deg' :
                print('Degrees')
                request += ' decimal,'
            else :     
                print(tableData[num-1])
                if '.' in tableData[num-1] :
                    if lf < 37 :
                        request += 'decimal,'
                        print('Decimal')
                    else :
                        request += ' float(8,4),'    
                        print('Float,')
                
                else :
                    print('Integer')                
                    #if lf < 5 :
                    #   request += ' smallint,'
                    #elif lf > 11 :
                    if lf > 11 :
                        request += ' bigint,'
                    else :
                        request += ' int,'
            print(line)
    request += " PRIMARY KEY (`" + keyCol + "`))"
    print(request)
    
    
    addFields = addFields[:-2]+')'
    addValues = addValues[:-2]+')'
    print(fieldCount)
    print("End of File")
                                       
    # Create Table
    print("Create Table")
    makeSQLrequest(cursor,request)   

    fd.close() 
    fp.close()
    
    print()
    addSpec = 'INSERT INTO '+table+addFields+' VALUES '+addValues
    #addSpec = 'INSERT INTO StellarMasses (CATAID, Z) VALUES(%s, %s)'
    print(addSpec)
    print()
    
    # Load Data into Table
    # Need Data as a List and pass to SQL as a tuple
    fd = open(tableFile,'r')
    count = 0
    head = [next(fd) for x in range(3)]
    for raw in head :
    #for raw in fd :
        line = raw.split()
        #line = [456+count, 5]
        #print(line)    
        print('Length : '+str(len(line)))
        req = tuple(line)
        print(req)
        makeSQLinsertRequest(cursor,addSpec,req)
        count = count + 1
        if count == 100 :
            cnx.commit()
            count = 0
         
    cursor.close()
    fd.close()
    print("End of File")
    

cnx = mysql.connector.connect(user='keith', password='kjhW0rthy#',
                              host='127.0.0.1',
                              database='SurveyData')

cursor = cnx.cursor()

DB_NAME = 'SurveyData'

for tab in tableFiles :
    createAndLoadTable(cnx,cursor,tab)
cnx.commit()
# Out:
# ['#', 'StellarMasses\n']
# Table : StellarMasses
# DROP TABLE StellarMasses
# OK
# ['#', 'StellarMasses']
# ['#', 'v08']
# ['#', '2012-12-07']
# ['#', 'Edward', 'Taylor', '<ent@physics.usyd.edu.au>']
# ['#']
# ['#', 'This', 'table', 'provides', 'stellar', 'masses,', 'restframe', 'photometry,', 'and', 'other']
# ['#', 'ancillary', 'stellar', 'population', 'parameters', 'from', 'stellar', 'population', 'fits']
# ['#', 'to', 'ugriz', 'SEDs', 'for', 'all', 'z', '<', '0.65', 'galaxies', 'in', 'the', 'GAMA', 'DR2', 'sample.']
# ['#']
# ['CATAID', '1', '-', 'meta.id;meta.main', 'Unique', 'ID', 'of', 'GAMA', 'object']
# Column : CATAID
# num : 1
# Found semi colon
# meta.id
# Integer
# ['CATAID', '1', '-', 'meta.id;meta.main', 'Unique', 'ID', 'of', 'GAMA', 'object']
# ['Z', '2', '-', 'src.redshift', 'Heliocentric', 'redshift']
# Column : Z
# num : 2
# src.redshift
# 0.1594800055027008
# Decimal
# ['Z', '2', '-', 'src.redshift', 'Heliocentric', 'redshift']
# ['nQ', '3', '-', 'meta.code.qual;src.redshift', 'Normalised', 'redshift', 'quality', '(use', 'nQ', '>', '2', 'for', 'science)']
# Column : nQ
# num : 3
# Found semi colon
# meta.code.qual
# 5
# Integer
# ['nQ', '3', '-', 'meta.code.qual;src.redshift', 'Normalised', 'redshift', 'quality', '(use', 'nQ', '>', '2', 'for', 'science)']
# ['SURVEY_CODE', '4', '-', 'meta.code;meta.dataset', 'Redshift', 'source', 'flag', '(5=GAMA;', '1=SDSS)']
# Column : SURVEY_CODE
# num : 4
# Found semi colon
# meta.code
# 1
# Integer
# ['SURVEY_CODE', '4', '-', 'meta.code;meta.dataset', 'Redshift', 'source', 'flag', '(5=GAMA;', '1=SDSS)']
# ['Z_TONRY', '5', '-', 'src.redshift', 'Flow', 'corrected', 'redshift', 'using', 'Tonry', 'et', 'al.', 'model']
# Column : Z_TONRY
# num : 5
# src.redshift
# 0.160882368683815
# Decimal
# ['Z_TONRY', '5', '-', 'src.redshift', 'Flow', 'corrected', 'redshift', 'using', 'Tonry', 'et', 'al.', 'model']
# ['fluxscale', '6', '-', 'arith.factor', 'Aperture', 'correction', 'factor', 'for', 'scaling', 'total', 'luminosities', 'and', 'stellar', 'masses', '(see', 'notes)']
# Column : fluxscale
# num : 6
# arith.factor
# 0.8555010975059942
# Decimal
# ['fluxscale', '6', '-', 'arith.factor', 'Aperture', 'correction', 'factor', 'for', 'scaling', 'total', 'luminosities', 'and', 'stellar', 'masses', '(see', 'notes)']
# ['zmax_19p4', '7', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '19.4', '(G09/G15', 'SURVEY_CLASS>=6', 'selection)']
# Column : zmax_19p4
# num : 7
# Found semi colon
# src.redshift
# 0.4215430919298244
# Decimal
# ['zmax_19p4', '7', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '19.4', '(G09/G15', 'SURVEY_CLASS>=6', 'selection)']
# ['zmax_19p8', '8', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '19.8', '(G12', 'SURVEY_CLASS>=6', 'selection)']
# Column : zmax_19p8
# num : 8
# Found semi colon
# src.redshift
# 0.4921731510283659
# Decimal
# ['zmax_19p8', '8', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '19.8', '(G12', 'SURVEY_CLASS>=6', 'selection)']
# ['zmax_17p88', '9', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '17.8', '(SDSS', 'main', 'survey', 'selection)']
# Column : zmax_17p88
# num : 9
# Found semi colon
# src.redshift
# 0.22056052183322544
# Decimal
# ['zmax_17p88', '9', '-', 'src.redshift;stat.max', 'Maximum', 'redshift', 'for', 'which', 'r_petro', '<=', '17.8', '(SDSS', 'main', 'survey', 'selection)']
# ['nbands', '10', '-', 'meta.number', 'Number', 'of', 'bands', 'used', 'in', 'SPS', 'fits', '(max.', 'is', '5;', 'NIR', 'data', 'have', 'not', 'been', 'used)']
# Column : nbands
# num : 10
# meta.number
# 5
# Integer
# ['nbands', '10', '-', 'meta.number', 'Number', 'of', 'bands', 'used', 'in', 'SPS', 'fits', '(max.', 'is', '5;', 'NIR', 'data', 'have', 'not', 'been', 'used)']
# ['logmstar', '11', 'dex', 'phys.mass', 'Stellar', 'mass', 'within', 'the', 'photometric', 'aperture', 'represented', 'as', 'log10(M_*/[M_Sol])', '(see', 'notes)']
# Column : logmstar
# num : 11
# phys.mass
# 9.95562616489304
# Decimal
# ['logmstar', '11', 'dex', 'phys.mass', 'Stellar', 'mass', 'within', 'the', 'photometric', 'aperture', 'represented', 'as', 'log10(M_*/[M_Sol])', '(see', 'notes)']
# ['dellogmstar', '12', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logmstar']
# Column : dellogmstar
# num : 12
# stat.error
# ['dellogmstar', '12', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logmstar']
# ['logmoverl_i', '13', 'dex', 'phys.composition.massLightRatio', 'Mass-to-light', 'ratio', '(restframe', 'i-band)', 'represented', 'as', 'log10(', '(M_*/L_i)', '/', '[M_Sol/L_Sol,i]', ')']
# Column : logmoverl_i
# num : 13
# phys.composition.massLightRatio
# 0.8574470896785518
# Decimal
# ['logmoverl_i', '13', 'dex', 'phys.composition.massLightRatio', 'Mass-to-light', 'ratio', '(restframe', 'i-band)', 'represented', 'as', 'log10(', '(M_*/L_i)', '/', '[M_Sol/L_Sol,i]', ')']
# ['dellogmoverl_i', '14', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logmoverl_i']
# Column : dellogmoverl_i
# num : 14
# stat.error
# ['dellogmoverl_i', '14', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logmoverl_i']
# ['logage', '15', 'dex', 'time.age', 'SPS', 'age', 'T', '=', 't(z_obs)', '-', 't(z_form),', 'represented', 'as', 'log10(T/[yr])']
# Column : logage
# num : 15
# time.age
# 7.996029680123902
# Decimal
# ['logage', '15', 'dex', 'time.age', 'SPS', 'age', 'T', '=', 't(z_obs)', '-', 't(z_form),', 'represented', 'as', 'log10(T/[yr])']
# ['dellogage', '16', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logage']
# Column : dellogage
# num : 16
# stat.error
# ['dellogage', '16', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logage']
# ['logtau', '17', 'dex', 'time.scale', 'SPS', 'e-folding', 'time', 'for', 'the', 'exponentially', 'declining', 'SFH,', 'represented', 'as', 'log10(tau/[yr])']
# Column : logtau
# num : 17
# time.scale
# 9.725150081285161
# Decimal
# ['logtau', '17', 'dex', 'time.scale', 'SPS', 'e-folding', 'time', 'for', 'the', 'exponentially', 'declining', 'SFH,', 'represented', 'as', 'log10(tau/[yr])']
# ['dellogtau', '18', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logtau']
# Column : dellogtau
# num : 18
# stat.error
# ['dellogtau', '18', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logtau']
# ['metal', '19', '-', 'phys.abund.Z', 'SPS', 'stellar', 'metallicity', '(Z_Sol', '=', '0.02)']
# Column : metal
# num : 19
# phys.abund.Z
# 0.020212358900238273
# Decimal
# ['metal', '19', '-', 'phys.abund.Z', 'SPS', 'stellar', 'metallicity', '(Z_Sol', '=', '0.02)']
# ['delmetal', '20', '-', 'stat.error', 'Formal', 'uncertainty', 'on', 'metal']
# Column : delmetal
# num : 20
# stat.error
# ['delmetal', '20', '-', 'stat.error', 'Formal', 'uncertainty', 'on', 'metal']
# ['extBV', '21', 'mag', 'phys.absorption', 'SPS', 'dust', 'obscuration;', 'for', 'Calzetti', 'et', 'al.', '(2003)', 'dust', 'A_V', '=', '3.1', 'x', 'E(B-V)']
# Column : extBV
# num : 21
# phys.absorption
# 0.24037740061548593
# Decimal
# ['extBV', '21', 'mag', 'phys.absorption', 'SPS', 'dust', 'obscuration;', 'for', 'Calzetti', 'et', 'al.', '(2003)', 'dust', 'A_V', '=', '3.1', 'x', 'E(B-V)']
# ['delextBV', '22', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'extBV']
# Column : delextBV
# num : 22
# stat.error
# ['delextBV', '22', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'extBV']
# ['logLWage', '23', 'dex', 'time.age', 'Restframe', 'i-band', 'luminosity', 'weighted', 'mean', 'stellar', 'age,', 'represented', 'as', 'log10(t*/[yr])']
# Column : logLWage
# num : 23
# time.age
# 7.478077951381866
# Decimal
# ['logLWage', '23', 'dex', 'time.age', 'Restframe', 'i-band', 'luminosity', 'weighted', 'mean', 'stellar', 'age,', 'represented', 'as', 'log10(t*/[yr])']
# ['dellogLWage', '24', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logLWage']
# Column : dellogLWage
# num : 24
# stat.error
# ['dellogLWage', '24', 'dex', 'stat.error', 'Formal', 'uncertainty', 'on', 'logLWage']
# ['gminusi', '25', 'mag', 'phot.color', 'Restframe', '(g-i)', 'colour', 'from', 'SED', 'fit']
# Column : gminusi
# num : 25
# phot.color
# 0.414568122677646
# Decimal
# ['gminusi', '25', 'mag', 'phot.color', 'Restframe', '(g-i)', 'colour', 'from', 'SED', 'fit']
# ['delgminusi', '26', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'gminusi']
# Column : delgminusi
# num : 26
# stat.error
# ['delgminusi', '26', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'gminusi']
# ['uminusr', '27', 'mag', 'phot.color', 'Restframe', '(u-r)', 'colour', 'from', 'SED', 'fit']
# Column : uminusr
# num : 27
# phot.color
# 0.5839355470502409
# Decimal
# ['uminusr', '27', 'mag', 'phot.color', 'Restframe', '(u-r)', 'colour', 'from', 'SED', 'fit']
# ['deluminusr', '28', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'uminusr']
# Column : deluminusr
# num : 28
# stat.error
# ['deluminusr', '28', 'mag', 'stat.error', 'Formal', 'uncertainty', 'on', 'uminusr']
# ['gminusi_stars', '29', 'mag', 'phot.color', 'Intrinsic,', 'stellar', '(g-i)', 'colour', 'from', 'SED', 'fit,', 'i.e.', 'corrected', 'for', 'internal', 'dust', 'obscuration']
# Column : gminusi_stars
# num : 29
# phot.color
# -0.06351243691393423
# Decimal
# ['gminusi_stars', '29', 'mag', 'phot.color', 'Intrinsic,', 'stellar', '(g-i)', 'colour', 'from', 'SED', 'fit,', 'i.e.', 'corrected', 'for', 'internal', 'dust', 'obscuration']
# ['uminusr_stars', '30', 'mag', 'phot.color', 'Intrinsic,', 'stellar', '(u-r)', 'colour', 'from', 'SED', 'fit,', 'i.e.', 'corrected', 'for', 'internal', 'dust', 'obscuration']
# Column : uminusr_stars
# num : 30
# phot.color
# -0.021127256697297293
# Decimal
# ['uminusr_stars', '30', 'mag', 'phot.color', 'Intrinsic,', 'stellar', '(u-r)', 'colour', 'from', 'SED', 'fit,', 'i.e.', 'corrected', 'for', 'internal', 'dust', 'obscuration']
# ['C_logM_ur', '31', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'uminusi', 'for', 'covariant', 'error', 'matrix']
# Column : C_logM_ur
# num : 31
# stat.correlation
# 0.9202311922482138
# Decimal
# ['C_logM_ur', '31', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'uminusi', 'for', 'covariant', 'error', 'matrix']
# ['C_logM_gi', '32', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'gminusi', 'for', 'covariant', 'error', 'matrix']
# Column : C_logM_gi
# num : 32
# stat.correlation
# 0.7861658098871203
# Decimal
# ['C_logM_gi', '32', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'gminusi', 'for', 'covariant', 'error', 'matrix']
# ['C_logM_eBV', '33', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'extBV', 'for', 'covariant', 'error', 'matrix']
# Column : C_logM_eBV
# num : 33
# stat.correlation
# 0.7714704261701232
# Decimal
# ['C_logM_eBV', '33', '-', 'stat.correlation', 'Correlation', 'coefficient', 'between', 'logmstar', 'and', 'extBV', 'for', 'covariant', 'error', 'matrix']
# ['fitphot_u', '34', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'u-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# Column : fitphot_u
# num : 34
# phot.mag
# 17.466169154098555
# Decimal
# ['fitphot_u', '34', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'u-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# ['delfitphot_u', '35', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_u']
# Column : delfitphot_u
# num : 35
# stat.error
# ['delfitphot_u', '35', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_u']
# ['absmag_u', '36', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'u-band', 'from', 'SPS', 'SED', 'fits']
# Column : absmag_u
# num : 36
# phys.magAbs
# -21.930272221267423
# Decimal
# ['absmag_u', '36', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'u-band', 'from', 'SPS', 'SED', 'fits']
# ['delabsmag_u', '37', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_u']
# Column : delabsmag_u
# num : 37
# stat.error
# ['delabsmag_u', '37', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_u']
# ['absmag_u_stars', '38', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'u-band']
# Column : absmag_u_stars
# num : 38
# phys.magAbs
# -23.402965001082777
# Decimal
# ['absmag_u_stars', '38', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'u-band']
# ['fitphot_g', '39', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'g-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# Column : fitphot_g
# num : 39
# phot.mag
# 17.09732777676826
# Decimal
# ['fitphot_g', '39', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'g-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# ['delfitphot_g', '40', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_g']
# Column : delfitphot_g
# num : 40
# stat.error
# ['delfitphot_g', '40', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_g']
# ['absmag_g', '41', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'g-band', 'from', 'SPS', 'SED', 'fits']
# Column : absmag_g
# num : 41
# phys.magAbs
# -22.323261336736966
# Decimal
# ['absmag_g', '41', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'g-band', 'from', 'SPS', 'SED', 'fits']
# ['delabsmag_g', '42', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_g']
# Column : delabsmag_g
# num : 42
# stat.error
# ['delabsmag_g', '42', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_g']
# ['absmag_g_stars', '43', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'g-band']
# Column : absmag_g_stars
# num : 43
# phys.magAbs
# -23.48434549791657
# Decimal
# ['absmag_g_stars', '43', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'g-band']
# ['fitphot_r', '44', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'r-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# Column : fitphot_r
# num : 44
# phot.mag
# 16.88813867348794
# Decimal
# ['fitphot_r', '44', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'r-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# ['delfitphot_r', '45', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_r']
# Column : delfitphot_r
# num : 45
# stat.error
# ['delfitphot_r', '45', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_r']
# ['absmag_r', '46', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'r-band', 'from', 'SPS', 'SED', 'fits']
# Column : absmag_r
# num : 46
# phys.magAbs
# -22.51379618110405
# Decimal
# ['absmag_r', '46', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'r-band', 'from', 'SPS', 'SED', 'fits']
# ['delabsmag_r', '47', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_r']
# Column : delabsmag_r
# num : 47
# stat.error
# ['delabsmag_r', '47', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_r']
# ['absmag_r_stars', '48', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'r-band']
# Column : absmag_r_stars
# num : 48
# phys.magAbs
# -23.380345443252033
# Decimal
# ['absmag_r_stars', '48', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'r-band']
# ['fitphot_i', '49', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'i-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# Column : fitphot_i
# num : 49
# phot.mag
# 16.72110338613352
# Decimal
# ['fitphot_i', '49', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'i-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# ['delfitphot_i', '50', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_i']
# Column : delfitphot_i
# num : 50
# stat.error
# ['delfitphot_i', '50', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_i']
# ['absmag_i', '51', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'i-band', 'from', 'SPS', 'SED', 'fits']
# Column : absmag_i
# num : 51
# phys.magAbs
# -22.738727036349324
# Decimal
# ['absmag_i', '51', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'i-band', 'from', 'SPS', 'SED', 'fits']
# ['delabsmag_i', '52', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_i']
# Column : delabsmag_i
# num : 52
# stat.error
# ['delabsmag_i', '52', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_i']
# ['absmag_i_stars', '53', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'i-band']
# Column : absmag_i_stars
# num : 53
# phys.magAbs
# -23.42053344236934
# Decimal
# ['absmag_i_stars', '53', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'i-band']
# ['fitphot_z', '54', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'z-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# Column : fitphot_z
# num : 54
# phot.mag
# 16.50190206247074
# Decimal
# ['fitphot_z', '54', 'mag', 'phot.mag', 'Best-fit', "observers'", 'frame', 'z-band', 'apparent', 'magnitude', 'from', 'SPS', 'SED', 'fits']
# ['delfitphot_z', '55', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_z']
# Column : delfitphot_z
# num : 55
# stat.error
# ['delfitphot_z', '55', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'fitphot_z']
# ['absmag_z', '56', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'z-band', 'from', 'SPS', 'SED', 'fits']
# Column : absmag_z
# num : 56
# phys.magAbs
# -22.93130557306192
# Decimal
# ['absmag_z', '56', 'mag', 'phys.magAbs', 'Absolute', 'magnitude', 'in', 'restframe', 'z-band', 'from', 'SPS', 'SED', 'fits']
# ['delabsmag_z', '57', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_z']
# Column : delabsmag_z
# num : 57
# stat.error
# ['delabsmag_z', '57', 'mag', 'stat.error', 'Formal', 'uncertainty', 'in', 'absmag_z']
# ['absmag_z_stars', '58', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'z-band']
# Column : absmag_z_stars
# num : 58
# phys.magAbs
# -23.46852398913652
# Decimal
# ['absmag_z_stars', '58', 'mag', 'phys.magAbs', 'Intrinsic', 'abs.', 'mag.', 'of', 'all', 'stellar', 'emission', '(i.e.', 'corrected', 'for', 'internal', 'dust', 'extinction)', 'in', 'restframe', 'z-band']
# CREATE TABLE `StellarMasses` ( `CATAID`  int(8), `Z` decimal, `nQ`  int, `SURVEY_CODE`  int, `Z_TONRY` decimal, `fluxscale` decimal, `zmax_19p4` decimal, `zmax_19p8` decimal, `zmax_17p88` decimal, `nbands`  int, `logmstar` decimal, `dellogmstar`  decimal, `logmoverl_i` decimal, `dellogmoverl_i`  decimal, `logage` decimal, `dellogage`  decimal, `logtau` decimal, `dellogtau`  decimal, `metal` decimal, `delmetal`  decimal, `extBV` decimal, `delextBV`  decimal, `logLWage` decimal, `dellogLWage`  decimal, `gminusi` decimal, `delgminusi`  decimal, `uminusr` decimal, `deluminusr`  decimal, `gminusi_stars` decimal, `uminusr_stars` decimal, `C_logM_ur` decimal, `C_logM_gi` decimal, `C_logM_eBV` decimal, `fitphot_u` decimal, `delfitphot_u`  decimal, `absmag_u` decimal, `delabsmag_u`  decimal, `absmag_u_stars` decimal, `fitphot_g` decimal, `delfitphot_g`  decimal, `absmag_g` decimal, `delabsmag_g`  decimal, `absmag_g_stars` decimal, `fitphot_r` decimal, `delfitphot_r`  decimal, `absmag_r` decimal, `delabsmag_r`  decimal, `absmag_r_stars` decimal, `fitphot_i` decimal, `delfitphot_i`  decimal, `absmag_i` decimal, `delabsmag_i`  decimal, `absmag_i_stars` decimal, `fitphot_z` decimal, `delfitphot_z`  decimal, `absmag_z` decimal, `delabsmag_z`  decimal, `absmag_z_stars` decimal, PRIMARY KEY (`CATAID`))
# 58
# End of File
# Create Table
# OK
#
# INSERT INTO StellarMasses(CATAID, Z, nQ, SURVEY_CODE, Z_TONRY, fluxscale, zmax_19p4, zmax_19p8, zmax_17p88, nbands, logmstar, dellogmstar, logmoverl_i, dellogmoverl_i, logage, dellogage, logtau, dellogtau, metal, delmetal, extBV, delextBV, logLWage, dellogLWage, gminusi, delgminusi, uminusr, deluminusr, gminusi_stars, uminusr_stars, C_logM_ur, C_logM_gi, C_logM_eBV, fitphot_u, delfitphot_u, absmag_u, delabsmag_u, absmag_u_stars, fitphot_g, delfitphot_g, absmag_g, delabsmag_g, absmag_g_stars, fitphot_r, delfitphot_r, absmag_r, delabsmag_r, absmag_r_stars, fitphot_i, delfitphot_i, absmag_i, delabsmag_i, absmag_i_stars, fitphot_z, delfitphot_z, absmag_z, delabsmag_z, absmag_z_stars) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Length : 58
# ('6802', '0.050540000200271606', '4', '5', '0.05181380361318588', '0.9698844270971212', '0.07210163498270844', '0.0855118455352105', '0.03674378893107175', '5', '9.128510421874514', '0.13451846013978278', '1.7044313846309378', '0.14569237325592868', '9.716151451346626', '0.257658495722723', '9.808104159005751', '0.1647744679511606', '0.03305363591337392', '0.01595973319132296', '0.14412448236451011', '0.10406645593202625', '9.090453740233892', '0.37995304332013025', '0.7684205586827612', '0.04529518581202734', '1.3860117165154502', '0.07237686459093044', '0.48734268167477696', '1.025210468081024', '0.31149631761284574', '0.35759246404920003', '-0.8765273789594149', '20.07844460324467', '0.055682957977253214', '-16.806528465022893', '0.04706378941710972', '-17.90865784676899', '19.135249293238438', '0.021400968342529303', '-17.733661153599154', '0.018479558511009242', '-18.55287325486609', '18.65158140208985', '0.016535743192044136', '-18.191282806527195', '0.01631558065751959', '-18.774967913562985', '18.3512695365845', '0.016114087920633464', '-18.502128808964724', '0.02035627554226102', '-18.95103825741829', '18.067006324078154', '0.03891390831366091', '-18.773940544780466', '0.04745838046169532', '-19.121348192347916')
# OK
# Length : 58
# ('6806', '0.33118999004364014', '4', '5', '0.3328041434288025', '1.039725578255899', '0.44048580527051245', '0.49357686151771796', '0.2607555931024589', '5', '11.05036017145426', '0.131280695720394', '1.719305270527936', '0.1252844427625714', '9.518861488695613', '0.3215335064032489', '9.750983773591061', '0.20645574379197376', '0.020266549150793015', '0.016058626709446716', '0.32505391740536693', '0.12746606477859096', '8.878217193354228', '0.4196405675211281', '0.9582561267180928', '0.09068467442524103', '1.6944864527890893', '0.058879368752887885', '0.3230023537439585', '0.882127046262031', '0.4775369916310286', '0.25982427382879575', '-0.526976743372324', '20.39731196589658', '0.06706320996749497', '-21.20474580247865', '0.029854060101405105', '-23.470315601490846', '19.662968477440348', '0.028490613306324606', '-22.321685364724924', '0.015458736720956432', '-24.043401612474213', '18.60516354507313', '0.015608452082808928', '-22.899009939175382', '0.02328419927660822', '-24.159982041776967', '18.19699949440295', '0.015797000254788043', '-23.282444395523886', '0.0646499239350739', '-24.272234743160134', '17.85355579437392', '0.03571428194099648', '-23.605778561019413', '0.12915292153848057', '-24.388580687796235')
# OK
# Length : 58
# ('6808', '0.22979000210762024', '4', '5', '0.231281116604805', '0.9197630070095798', '0.2842998768035877', '0.3258353541357761', '0.16255064111509687', '5', '10.847068928994867', '0.10739308640399128', '1.973622020314257', '0.10309286514571421', '9.831041066965284', '0.1527750375502285', '9.472009764233583', '0.3199034696490353', '0.0184374417907734', '0.013195368702517337', '0.17367464369647037', '0.1299151614296119', '9.506484597620977', '0.23945192128193668', '1.1133036805948595', '0.08339692181723846', '2.0801286259944445', '0.08377666328370352', '0.7800180505537958', '1.6465237642196016', '0.13310129794968026', '0.5967746677820959', '0.1128725838012354', '21.12838019252811', '0.15791821013203347', '-19.672758252739342', '0.054236540949260455', '-21.058941709236027', '19.960452042066052', '0.04152070291970122', '-21.034746190471115', '0.022163867616436576', '-22.044568774189738', '18.853521657638815', '0.02429284009947506', '-21.751186696137076', '0.01782404126249382', '-22.480193945011038', '18.368304556167132', '0.017302660826424034', '-22.149290491832804', '0.04937623933702888', '-22.717535089737435', '18.00813468588994', '0.04352033915949868', '-22.458753913749376', '0.08931416924642711', '-22.903263346524938')
# OK
# End of File
