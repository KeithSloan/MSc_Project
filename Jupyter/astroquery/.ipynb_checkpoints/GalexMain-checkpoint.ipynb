# %%
from astroquery.gama import GAMA
result = GAMA.query_sql('SELECT * FROM GalexMain LIMIT 20')

# %%
print(result)
# Out:
# CATAID       OBJID             RA      ... NN_POSANG_NUV NN_POSANGERR_NUV
# ------ ------------------ ------------ ... ------------- ----------------
#   6505 588848900983357543 173.05607838 ...       20.8528           22.984
#   6506 588848900983357558 173.05283934 ...        -999.0           -999.0
#   6507 588848900983357560 173.04984113 ...        -999.0           -999.0
#   6509 588848900983357580 173.08999395 ...        30.429          37.3479
#   6510 588848900983357588 173.08993864 ...        -999.0           -999.0
#   6513 588848900983357599 173.09278167 ...        -999.0           -999.0
#   6520 588848900983357700 173.09090354 ...       172.153          9.77999
#   6545 588848900983422981 173.09665438 ...        -999.0           -999.0
#   6546 588848900983423050 173.19191662 ...        26.222          30.0574
#   6550 588848900983423131 173.14336061 ...       169.869          9.72349
#   6553 588848900983423142 173.15319997 ...        173.86          12.1692
# ...
